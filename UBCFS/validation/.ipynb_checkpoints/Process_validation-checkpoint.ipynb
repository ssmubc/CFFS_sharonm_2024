# %%
import pandas as pd
from pandas.util.testing import assert_frame_equal
import numpy as np
# Out:
# C:\Users\smvan\AppData\Local\Temp\ipykernel_18704\679328059.py:2: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# # Validating Results

# %%
def equal_dataframes(df1, df2):
    try:
        assert_frame_equal(df1, df2)
        return print("They are equal!")
    except:
        return print("They are not equal.")

# %% [markdown]
# ## Validating results on OK21-22

# %%
Jenny_results = pd.read_csv("Jenny_results_OK21_22.csv")
Jenny_results = Jenny_results.drop(["GHG Only Label", "Combined Label"], axis=1)
Jenny_results
# Out:
#       ProdId                     Description        SalesGroup   Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO   185.000000
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO   140.000000
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO   245.000000
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO   215.000000
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO   233.000000
# ..       ...                             ...               ...          ...
# 453  R-57815  SQR|Tofu Sofrito Quesadilla +1  OK - SQUARE MEAL   650.000002
# 454  R-61679  SQR|Tofu Sofrito Quesadilla +2  OK - SQUARE MEAL  1065.000002
# 455  R-56902          SQR|Vegan Lettuce Wrap  OK - SQUARE MEAL   399.999993
# 456  R-57810       SQR|Vegan Lettuce Wrap +1  OK - SQUARE MEAL   544.999993
# 457  R-57811       SQR|Vegan Lettuce Wrap +2  OK - SQUARE MEAL   689.999993
#
# ...

# %%
Silvia_results = pd.read_csv("Silvia_results_OK21_22.csv")
Silvia_results
# Out:
#       ProdId                     Description        SalesGroup   Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO   185.000000
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO   140.000000
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO   245.000000
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO   215.000000
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO   233.000000
# ..       ...                             ...               ...          ...
# 453  R-57815  SQR|Tofu Sofrito Quesadilla +1  OK - SQUARE MEAL   650.000002
# 454  R-61679  SQR|Tofu Sofrito Quesadilla +2  OK - SQUARE MEAL  1065.000002
# 455  R-56902          SQR|Vegan Lettuce Wrap  OK - SQUARE MEAL   399.999993
# 456  R-57810       SQR|Vegan Lettuce Wrap +1  OK - SQUARE MEAL   544.999993
# 457  R-57811       SQR|Vegan Lettuce Wrap +2  OK - SQUARE MEAL   689.999993
#
# ...

# %%
equal_dataframes(Silvia_results, Jenny_results)
# Out:
# They are equal!

# %% [markdown]
# #### Deliberately change a value of single cell to confirm that the function is working properly.

# %%
# Try changing a value in Jenny_results to confirm if the above function is working properly
Jenny_results.at[0, "Weight (g)"] = 180.0
Jenny_results
# Out:
#       ProdId                     Description        SalesGroup   Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO   180.000000
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO   140.000000
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO   245.000000
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO   215.000000
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO   233.000000
# ..       ...                             ...               ...          ...
# 453  R-57815  SQR|Tofu Sofrito Quesadilla +1  OK - SQUARE MEAL   650.000002
# 454  R-61679  SQR|Tofu Sofrito Quesadilla +2  OK - SQUARE MEAL  1065.000002
# 455  R-56902          SQR|Vegan Lettuce Wrap  OK - SQUARE MEAL   399.999993
# 456  R-57810       SQR|Vegan Lettuce Wrap +1  OK - SQUARE MEAL   544.999993
# 457  R-57811       SQR|Vegan Lettuce Wrap +2  OK - SQUARE MEAL   689.999993
#
# ...

# %%
equal_dataframes(Silvia_results, Jenny_results)
# Out:
# They are not equal.

# %% [markdown]
# ## Validating results on OK22-23

# %%
Silvia_results_new = pd.read_csv("Silvia_results_OK22_23_ver2.csv")
Silvia_results_new
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 218  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 219  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 220  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 221  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 222  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
Jenny_results_new = pd.read_csv("Data_Labelled_OK22-23.csv")
Jenny_results_new = Jenny_results_new.drop(["GHG Only Label", "Combined Label"], axis=1)
Jenny_results_new
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 218  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 219  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 220  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 221  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 222  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
equal_dataframes(Silvia_results_new, Jenny_results_new)
# Out:
# They are equal!

# %% [markdown]
# ### Find out which two rows return inconsistent values

# %%
# Finds out which rows are different between two dataframes. 
## Returns nothing if there is no difference between two dataframes. 

def diff_dataframes(df1, df2):
    diff_df = df1[(df2 != df1).any(axis=1)]
    return diff_df

# %%
diff_dataframes(Jenny_results_new, Silvia_results_new)
# Out:
# Empty DataFrame
# Columns: [ProdId, Description, SalesGroup, Weight (g), GHG Emission (g), N lost (g), Freshwater Withdrawals (L), Stress-Weighted Water Use (L), GHG Emission (g) / 100g, N lost (g) / 100g, Freshwater Withdrawals (L) / 100g, Stress-Weighted Water Use (L) / 100g]
# Index: []
