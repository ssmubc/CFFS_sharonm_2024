# %%
import pandas as pd

# %%
mapped = pd.read_csv("notebook3_checkpoint.csv")
mapped
# Out:
#        ItemId  CategoryID                Description  CaseQty CaseUOM  PakQty  \
# 0     I-57545         1.0    CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1     I-10869         1.0        BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2      I-7064         1.0      BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3     I-37005         1.0             BEEF MEATBALLS     4.54      Kg  1000.0
# 4     I-37002         1.0   BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
# ...       ...         ...                        ...      ...     ...     ...
# 2003  I-19464         NaN    NOODLES RICE VERMICELLI    30.00     pak   400.0
# 2004   I-3701         NaN         NUT 1KG PISTACHIO      1.00      Kg     1.0
# 2005  I-29755         NaN     PEAS GREEN WASABI BULK  5000.00       g     1.0
# 2006   I-4524         NaN               BEETS GOLDBC     5.00      lb     1.0
# 2007   I-1271         NaN  LOAF MARBLE RYE SANDWICH      4.00    LOAF     1.0
#
# ...

# %%
mapped.tail(20)
# Out:
#        ItemId  CategoryID                    Description  CaseQty CaseUOM  \
# 1988  I-62863        59.0  CK|G&G|HMR|Meat Ball & Pasta.      1.0      ea
# 1989  I-19923        12.0           HALIBUT STEAK 4OZ.OW      1.0      lb
# 1990   I-8105        12.0             SAL LOX SMK SLC OW      1.0      lb
# 1991   I-3094        54.0        PEPPERCORN BLACK WHOLE       3.0      Kg
# 1992  I-16060        54.0                   SUMAC GROUND      1.0    each
# 1993  I-68718         NaN    BUN HAMBURGER WW VEGAN 85GR      1.0    each
# 1994  I-68700         NaN      EGG CKD FOLDED  VEGAN FRZ     60.0    each
# 1995  I-54711         NaN     CHEESE HALLOUMI TRE STELLE      6.0     pak
# 1996   I-4757         NaN                    ONIONS RED      25.0      lb
# 1997  I-36794         NaN           RICE BASMATI INDIAN       1.0      ea
# 1998   I-3582         NaN         SEASONING MONTREAL STK      3.4      Kg
# 1999  I-65714         NaN         CHUTNEY MANGO-TAMARIND      2.0      un
# ...

# %%
mapped["CategoryID"].isnull().sum()
# Out:
# 15
