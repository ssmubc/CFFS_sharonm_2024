# %%
import pandas as pd
import numpy as np

# %%
OK22 = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23.csv")
OK22
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 OK22 = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23.csv")
#       2 OK22
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
OK22.loc[OK22["ProdId"] == "R-56902"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 OK22.loc[OK22["ProdId"] == "R-56902"]
#
# NameError: name 'OK22' is not defined

# %%
r1 = pd.read_csv("practice/products_check2.csv")
r1.loc[r1["ProdId"] == "R-56493"]

# %%
ingre.loc[ingre["Recipe"] == "R-56493"]

# %%
conversions = pd.read_csv("data_origin/cleaning/Conversions_Added.csv")
conversions

# %%
conversions.loc[conversions["ConversionId"] == "P-46862"]

# %%
p1 = pd.read_csv("practice/get_items_checkpoint.csv")
p1

# %%
plink = pd.read_csv("practice/link_prep_checkpoint.csv")
plink.loc[plink["PrepId"] == "P-46862"]

# %%
p1.loc[p1["PrepId"] == "P-46862"]

# %%
manual = pd.read_csv("data_origin/cleaning/update/Preps_UpdateUom.csv")
manual

# %%
manual.loc[manual["PrepId"] == "P-46862"]

# %%
preps_cleaned = pd.read_csv("data_origin/cleaning/Preps_List_Cleaned.csv")
preps_cleaned

# %%
preps_cleaned.loc[preps_cleaned["PrepId"] == "P-46862"]

# %%
origin = pd.read_csv("data_origin/final/Data_Labelled_OK_origin.csv")
origin.head(50)
# Out:
#      ProdId                     Description                   SalesGroup  \
# 0   R-61778          ALF|Flatbread|4 Cheese                OK - AL FORNO
# 1   R-61780  ALF|Flatbread|Apple & Pancetta                OK - AL FORNO
# 2   R-61749       ALF|Flatbread|BBQ Chicken                OK - AL FORNO
# 3   R-50859        ALF|Flatbread|Bruschetta                OK - AL FORNO
# 4   R-50788           ALF|Flatbread|Caprese                OK - AL FORNO
# 5   R-61781   ALF|Flatbread|Chick Artichoke                OK - AL FORNO
# 6   R-50858             ALF|Flatbread|Greek                OK - AL FORNO
# 7   R-61498     ALF|Flatbread|Hawaii Five-0                OK - AL FORNO
# 8   R-50562           ALF|Flatbread|Italian                OK - AL FORNO
# 9   R-56337     ALF|Flatbread|Mediterranean                OK - AL FORNO
# 10  R-61782          ALF|Flatbread|Mushroom                OK - AL FORNO
# 11  R-61779    ALF|Flatbread|Mushroom Pesto                OK - AL FORNO
# ...

# %%
new = pd.read_csv("data/final/Data_Labelled_OK22-23.csv")
new
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 218  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 219  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 220  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 221  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 222  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
origin.loc[origin["ProdId"] == "R-30406"]
# Out:
#      ProdId                  Description      SalesGroup  Weight (g)  \
# 59  R-30406  G&G|Croissant|Multigrain|OK  OK - GRAB & GO  120.000005
#
#     GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 59        182.700007       1.776                        50.3
#
#     Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 59                         1538.6                   152.25               1.48
#
#     Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 59                              41.92                               1282.17
#
#    GHG Only Label Combined Label
# 59          Green         Yellow

# %%
new.loc[new["ProdId"] == "R-30406"]
# Out:
#     ProdId                   Description      SalesGroup  Weight (g)  \
# 0  R-30406  G&G|Croissant|Multigrain|OK   OK - GRAB & GO  120.000005
#
#    GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 0        182.700007       1.776                        50.3
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                         1538.6                   152.25               1.48
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                              41.92                               1282.17
#
#   GHG Only Label Combined Label
# 0          Green         Yellow

# %%
origin.to_csv("Jenny_results_OK21_22.csv", index=False)

# %%
origin.loc[origin["ProdId"] == "R-42369"]

# %%
ingre = pd.read_csv("data_origin/preprocessed/Ingredients_List.csv")
ingre

# %%
ingre.loc[ingre["Recipe"] == "R-42369"]

# %%
mapped = pd.read_csv("data_origin/mapping/Mapping.csv")
mapped
