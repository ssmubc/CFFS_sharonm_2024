# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23_with_name.csv")
df
# Out:
#             Displayed Name   ProdId                   Description  \
# 0                      NaN  R-30406  G&G|Croissant|Multigrain|OK
# 1               B'Fast BLT  R-55155             GRL|Breakfast BLT
# 2    B'Fast Wrap (various)  R-44024            GRL|Breakfast Wrap
# 3         B'Fast Croissant  R-50368        GRL|BreakfastCroissant
# 4     Apple Cinnamon Crepe  R-50498      GRL|Crepe|Apple Cinnamon
# ..                     ...      ...                           ...
# 218    Chicken Caesar Wrap  R-68143  SANDWICH|Chicken Caesar Wrap
# 219            Grilled Veg  R-61321          SANDWICH|Grilled Veg
# 220            Veg Bahn Mi  R-68075         SANDWICH|Tofu Bahn Mi
# 221                   Miso  R-37630                SIDE|Soup|Miso
# 222            Incredibowl  R-27383               VEG|Incredibowl
#
#                        SalesGroup   Weight (g)  GHG Emission (g)  N lost (g)  \
# 0                  OK - GRAB & GO   120.000005        182.700007    1.776000
# 1    OK - GRILL KITCHEN BREAKFAST   389.999981       1173.197553   14.668932
# 2    OK - GRILL KITCHEN BREAKFAST   300.500002       1651.867478   23.085994
# 3    OK - GRILL KITCHEN BREAKFAST   314.250005       1061.347040   11.834719
# 4    OK - GRILL KITCHEN BREAKFAST   400.000010        629.156129    3.853725
# ..                            ...          ...               ...         ...
# 218  OK - SANDWICH KITCHEN EVENTS   300.000005        866.096378   16.268688
# 219  OK - SANDWICH KITCHEN EVENTS  1040.000000       1667.023685   15.752278
# 220         OK - SANDWICH KITCHEN   226.000001        435.431612    2.109501
# 221                    OK - SOUP    454.000000         92.157573    0.317005
# 222       OK - VEGETARIAN KITCHEN   335.600000        276.287629    1.549379
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                         50.30                        1538.60
# 1                        239.33                        7306.12
# 2                        298.64                        9031.01
# 3                        179.73                        5963.38
# 4                        112.61                        3188.56
# ..                          ...                            ...
# 218                      101.02                        2411.81
# 219                      415.31                       13510.07
# 220                       21.21                         658.92
# 221                        0.89                           5.48
# 222                       79.06                        3593.70
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                     152.25               1.48
# 1                     300.82               3.76
# 2                     549.71               7.68
# 3                     337.74               3.77
# 4                     157.29               0.96
# ..                       ...                ...
# 218                   288.70               5.42
# 219                   160.29               1.51
# 220                   192.67               0.93
# 221                    20.30               0.07
# 222                    82.33               0.46
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                41.92                               1282.17
# 1                                61.37                               1873.36
# 2                                99.38                               3005.33
# 3                                57.19                               1897.65
# 4                                28.15                                797.14
# ..                                 ...                                   ...
# 218                              33.67                                803.94
# 219                              39.93                               1299.05
# 220                               9.38                                291.56
# 221                               0.20                                  1.21
# 222                              23.56                               1070.83
#
#     GHG Only Label Combined Label
# 0            Green         Yellow
# 1           Yellow         Yellow
# 2              Red            Red
# 3           Yellow            Red
# 4            Green          Green
# ..             ...            ...
# 218         Yellow         Yellow
# 219          Green         Yellow
# 220         Yellow          Green
# 221          Green          Green
# 222          Green          Green
#
# [223 rows x 15 columns]

# %%
df[df["Displayed Name"].isnull()]
# Out:
#     Displayed Name   ProdId                   Description  \
# 0              NaN  R-30406  G&G|Croissant|Multigrain|OK
# 24             NaN  R-38518     SQR|Citrus Cous-Cous 170g
# 30             NaN  R-45134         SQR|Lentil Loaf|Vegan
# 85             NaN  R-61655         GRL|Salad|Caesar|SIDE
# 147            NaN  R-62503           SQR|Grilled Salmon
# 186            NaN  R-54652          SQR|Pork Char Siu +1
#
#                  SalesGroup  Weight (g)  GHG Emission (g)  N lost (g)  \
# 0            OK - GRAB & GO  120.000005        182.700007    1.776000
# 24         OK - SQUARE MEAL  170.000000        141.073878    1.196145
# 30         OK - SQUARE MEAL  270.000000        369.919649    1.926803
# 85   OK - GRILL KITCHEN DAY  145.500000        234.477312    2.125959
# 147        OK - SQUARE MEAL  135.000000        649.898381    8.577020
# 186        OK - SQUARE MEAL  220.000000       1424.640908   17.405744
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                         50.30                        1538.60
# 24                        31.23                         960.76
# 30                        53.15                        2321.67
# 85                        31.37                        1518.99
# 147                      189.04                        1119.02
# 186                      310.48                        7187.57
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                     152.25               1.48
# 24                     82.98               0.70
# 30                    137.01               0.71
# 85                    161.15               1.46
# 147                   481.41               6.35
# 186                   647.56               7.91
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                41.92                               1282.17
# 24                               18.37                                565.15
# 30                               19.69                                859.88
# 85                               21.56                               1043.98
# 147                             140.03                                828.90
# 186                             141.13                               3267.08
#
#     GHG Only Label Combined Label
# 0            Green         Yellow
# 24           Green          Green
# 30           Green          Green
# 85           Green          Green
# 147            Red            Red
# 186            Red            Red

# %%
ingre = pd.read_csv("data/preprocessed/Ingredients_List.csv")
ingre
# Out:
#     IngredientId      Qty   Uom  Conversion  InvFactor   Recipe
# 0         I-3643   225.00     g     0.00100     0.1837  P-18907
# 1         I-6026  1000.00     g     1.00000     0.8163  P-18907
# 2         I-6807     2.27    Kg     2.20462     1.4188  P-19175
# 3         I-4698    10.00    Kg     4.00000     1.3514  P-20239
# 4         I-4381     1.00    lb     1.00000     1.1111  P-24452
# ..           ...      ...   ...         ...        ...      ...
# 498      I-15032     0.15  LOAF     1.00000     1.0000  R-69126
# 499       I-2156    40.00     g     0.00100     1.0000  R-69126
# 500       I-3625     1.00     g     1.00000     1.0000  R-69126
# 501       I-8060    10.00     g     1.00000     1.0000  R-69126
# 502      P-64884    30.00     g     0.00100     1.0000  R-69126
#
# [503 rows x 6 columns]

# %%
items = pd.read_csv("data/preprocessed/Items_List.csv")
items
# Out:
#       ItemId                   Description  CaseQty CaseUOM   PakQty PakUOM  \
# 0     I-3617       ALLSPICE GROUND SHAKER       8.0    each  454.000      g
# 1     I-4472                    AVOCADO MX     20.0      CT    1.000     CT
# 2     I-4973           AVOCADO PULP CHUNKY      6.0    each  907.185      g
# 3    I-65741    BACON 2.5MM NATURALLY SMKD      5.0      Kg    1.000     Kg
# 4    I-27410      BACON 3MM NATURALLY SMKD      5.0      Kg    1.000     Kg
# ..       ...                           ...      ...     ...      ...    ...
# 257   I-4920                    TOMATILLOS     10.0      lb    1.000     lb
# 258  I-17159           TOMATOES GRAPE 10LB     10.0      lb    1.000     lb
# 259   I-9341             TORTILLA FLOUR 6"     24.0     pak   12.000     CT
# 260   I-1152  TORTILLA FLOUR W/ WHEAT 12IN     12.0     pak   10.000     CT
# 261  I-27407      TURKEY SAUSAGE BREAKFAST     20.0      ea    1.000     ea
#
#     InventoryGroup
# 0           SPICES
# 1          PRODUCE
# 2          PRODUCE
# 3             MEAT
# 4             MEAT
# ..             ...
# 257        PRODUCE
# 258        PRODUCE
# 259    BAKED GOODS
# 260    BAKED GOODS
# 261        POULTRY
#
# [262 rows x 7 columns]

# %%
items.loc[items["ItemId"] == "I-3914"]
# Out:
#     ItemId                   Description  CaseQty CaseUOM  PakQty PakUOM  \
# 80  I-3914  HOT DOG VEG 7IN 5/LB FZN TFC     10.0      lb     5.0     CT
#
#    InventoryGroup
# 80           MEAT
