# %% [markdown]
# # Labelling Recipes Stage
# **Sharon Marfatia**

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifty_cutoff = 191.12
# is the overall baseline supposed to be the GHG_baseline?
overall_baseline = 382.25

GHG_baseline = 382.25
nitrogen_baseline = 3.86
water_baseline = 1248.19
land_baseline = 0.93

# %%
# CHANGE THIS AS NEEDED:
restaurant_name = "AMS_Gallery23-24"
# restaurant_name = "OK23-24"
# restaurant_name = "Gather23-24"
# restaurant_name = "Totem23-24"

# %%
def create_ghg_label(label):
    # determine the GHG label based on the given label value and predefined cutoffs
    if label > overall_baseline:
        # if the label value is > than overall baseline, assign "Red" label
        return "Red"
    elif (label <= overall_baseline) & (label > fifty_cutoff):
        # if the label value is between overall baseline and fifty_cutoff, assign "Yellow" label
        return "Yellow"
    elif label <= fifty_cutoff:
        # if the label value is less than or equal to the fifty_cutoff, assign "Green" label
        return "Green"

# %%
def create_results_all_factors(df):
    # create a Combined Label based on different factors for each row in the DataFrame
    df["Combined Label"] = ""

    # add another parameter: n so that change the number of factors instead of multiplying by 3

    def calculate_all_factors(ghg, nitrogen, water, land):
        # calculate the combined label value based on the given factors
        weighted_ghg = ghg / (4 * GHG_baseline)
        weighted_nitrogen = nitrogen / (4 * nitrogen_baseline)
        weighted_water = water / (4 * water_baseline)

        # most recently added
        weighted_land = land / (4 * land_baseline)

        return weighted_ghg + weighted_nitrogen + weighted_water + weighted_land


    for ind, row in df.iterrows():
        # iterate over each row in the DataFrame and calculate the combined label
        label = calculate_all_factors(row["GHG Emission (g) / 100g"], row["N lost (g) / 100g"],
                                      row["Stress-Weighted Water Use (L) / 100g"],
                                      row['Land Use (m^2) / 100g'])

        if label <= 0.5:
            # if the label value is less than or equal to 0.5, assign "Green" label
            df.loc[ind, "Combined Label"] = "Green"
        elif label >= 1:
            # if the label value is greater than or equal to 1, assign "Red" label
            df.loc[ind, "Combined Label"] = "Red"
        elif (label > 0.5) or (label < 1):
            # if the label value is between 0.5 and 1, assign "Yellow" label
            df.loc[ind, "Combined Label"] = "Yellow"
    return df

# %%
# Sharon: Updated function Nov 21 2023
# Fixes KeyError: 1
def add_menu_names(df, mapping_dict):
    # Add menu names to the DataFrame based on a dictionary
    df["Displayed Name"] = ""
    menu_name = list(mapping_dict.keys())
    menu_ID = list(mapping_dict.values())
    for ind, row in df.iterrows():
        searchID = row["ProdId"]
        if searchID in menu_ID:
            position = menu_ID.index(searchID)
            name = menu_name[position]
            df.at[ind, "Displayed Name"] = name

    name_col = df.pop("Displayed Name")
    df.insert(0, "Displayed Name", name_col)
    df = df.dropna(subset=["Displayed Name"])

    df_temp = df["Displayed Name"].str.split("|", expand=True)
    df["Category"] = df_temp[0]

    # Ensure that 'Displayed Name' is updated only if there is a second column
    if len(df_temp.columns) > 1:
        df["Displayed Name"] = df_temp[1]
    else:
        df["Displayed Name"] = ""

    name_col2 = df.pop("Category")
    df.insert(0, "Category", name_col2)
    return df



# def add_menu_names(df, dict):
#     # add menu names to the DataFrame based on a dictionary
#     df["Displayed Name"] = ""
#     menu_name = list(dict.keys())
#     menu_ID = list(dict.values())
#     for ind, row in df.iterrows():
#         searchID = row["ProdId"]
#         if searchID in menu_ID:
#             # if the product ID is found in the menu_ID list, retrieve the corresponding name
#             position = menu_ID.index(searchID)
#             name = menu_name[position]
#             df.loc[ind, "Displayed Name"] = name
#         else:
#             continue
#     name_col = df.pop("Displayed Name")
#     df.insert(0, "Displayed Name", name_col)
#     df = df.dropna(subset=["Displayed Name"])

#     df_temp = df["Displayed Name"].str.split("|", expand=True)
#     df["Category"] = df_temp[0]
#     df["Displayed Name"] = df_temp[1]
#     name_col2 = df.pop("Category")
#     df.insert(0, "Category", name_col2)
#     # returns the modified DataFrame with the added "Category" and "Displayed Name" columns
#     return df

# %%
def create_final_counts(df):
    # create final counts of GHG and combined labels from DataFrame

    # count the occurrences of GHG Only labels
    ghg_red = df["GHG Only Label"].value_counts()["Red"]
    ghg_yellow = df["GHG Only Label"].value_counts()["Yellow"]
    ghg_green = df["GHG Only Label"].value_counts()["Green"]
    # count the occurrences of Combined labels
    all_red = df["Combined Label"].value_counts()["Red"]
    all_yellow = df["Combined Label"].value_counts()["Yellow"]
    all_green = df["Combined Label"].value_counts()["Green"]
    print(all_red, all_yellow, all_green)
    # create a dictionary to store the label counts
    data = {"GHG Label Counts": [ghg_red, ghg_yellow, ghg_green],
            "Combined Label Counts": [all_red, all_yellow, all_green]}
    # create a DataFrame from the label counts data and return it
    results = pd.DataFrame(data, index=["Red", "Yellow", "Green"])
    return results

# %%
def create_visualizations(df):
    df.reset_index(inplace=True)
    df = df.rename(columns={"index": "Color"})
    sns.set_theme(style="darkgrid")
    palette = {"Green": "tab:green", "Red": "tab:red", "Yellow": "tab:orange", "Sum": "tab:blue"}
    fig, axes = plt.subplots(1, 2, figsize=(7, 4), sharex=False, sharey=True)
    fig.suptitle("Emission Label Counts")
    ax1 = sns.barplot(data=df, x=df["Color"], y=df["GHG Label Counts"], ax=axes[0], palette=palette)
    ax1.set_title("GHG Emission Label")
    ax1.set_ylabel("Counts")
    ax1.set_xlabel("")
    ax2 = sns.barplot(data=df, x=df["Color"], y=df["Combined Label Counts"], ax=axes[1], palette=palette)
    ax2.set_title("Combined Emissions Label")
    ax2.set_ylabel("")
    ax2.set_xlabel("")
    fig.title = "Color Comparison"
    ax1.set_title = "GHG Emission Label Counts"
    ax2.set_title = "Combined Emissions Label Counts"
    ax2.set_ylabel = ""
    for ax in [ax1, ax2]:
        for i in ax.containers:
            ax.bar_label(i, )
    plt.tight_layout()
    plt.savefig("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Summary_fig.png")
    plt.show()

# %%
def create_category_true(df):
    # create category columns for True values in the DataFrame

    # create empty columns for each category
    df["RED"] = ""
    df["YELLOW"] = ""
    df["GREEN"] = ""
    # iterate over each row in the DataFrame
    for ind, row in df.iterrows():
        # Check the value of the Combined Label column and assign "TRUE" to the corresponding category column
        if row["Combined Label"] == "Red":
            df.loc[ind, "RED"] = "TRUE"
        if row["Combined Label"] == "Yellow":
            df.loc[ind, "YELLOW"] = "TRUE"
        if row["Combined Label"] == "Green":
            df.loc[ind, "GREEN"] = "TRUE"
    # adds category columns for True values based on the Combined Label column
    return df

# %%
products = pd.read_csv('C:/Users/smvan/CFFS-S23/CFFS-22-23/data/preprocessed/AMS_data/Products_List.csv')

# %%
final = products.copy()
final
# Out:
#       ProdId                    Description SalesGroup    Weight (g)  \
# 0    R-17284   2022 goose & Watermelon bull          N     97.573505
# 1    R-18292         Vegan Caesar wrap 2022          N    437.897042
# 2    R-15423          "Pulled Pork" Sliders          N    208.720500
# 3     R-6243            2019 Chipotle Aioli          N  32258.000000
# 4    R-13758           2019 Falafel Edamame          Y  29669.000000
# ..       ...                            ...        ...           ...
# 286  R-18272    Truffle Mushroom Pasta 2023          N    342.824999
# 287  R-15427            Vegan Chipotle Mayo          N   1150.000000
# 288  R-15426            Vegan Tofu Scramble          N     50.280000
# 289  R-15544                   VEGGIE BENNY          N    225.000000
# 290  R-18675     Veggie Burger Special 2023          N    294.544996
#
#      GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0           26.842002    0.183600        0.028850                        2.54
# 1          409.785901    3.392543        2.000068                       29.07
# 2         1054.955596   13.558082        2.451705                      210.91
# 3        70693.846600  429.368800       80.947380                      735.25
# 4        42505.028100  161.011300      177.832190                      363.29
# ..                ...         ...             ...                         ...
# 286       1539.977637    8.291102        2.927251                       84.69
# 287       9370.300000    7.762500       31.000000                       27.93
# 288         48.810812    0.339712        0.087333                        2.22
# 289        342.127000    1.802500        1.816600                       21.78
# 290        294.344507    2.229055        0.903210                       33.65
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 0                            90.18                    27.51
# 1                          1081.32                    93.58
# 2                          6351.04                   505.44
# 3                        330063.55                   219.15
# 4                         12654.87                   143.26
# ..                             ...                      ...
# 286                        5556.78                   449.20
# 287                         390.54                   814.81
# 288                          18.30                    97.08
# 289                         678.34                   152.06
# 290                        1149.94                    99.93
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 0                 0.19                               2.60
# 1                 0.77                               6.64
# 2                 6.50                             101.05
# 3                 1.33                               2.28
# 4                 0.54                               1.22
# ..                 ...                                ...
# 286               2.42                              24.70
# 287               0.68                               2.43
# 288               0.68                               4.42
# 289               0.80                               9.68
# 290               0.76                              11.42
#
#      Stress-Weighted Water Use (L) / 100g  Land Use (m^2) / 100g
# 0                                   92.42                   0.03
# 1                                  246.93                   0.46
# 2                                 3042.84                   1.17
# 3                                 1023.20                   0.25
# 4                                   42.65                   0.60
# ..                                    ...                    ...
# 286                               1620.88                   0.85
# 287                                 33.96                   2.70
# 288                                 36.40                   0.17
# 289                                301.48                   0.81
# 290                                390.41                   0.31
#
# [291 rows x 14 columns]

# %%
final["GHG Only Label"] = final["GHG Emission (g) / 100g"].apply(lambda x: create_ghg_label(x))
final
# Out:
#       ProdId                    Description SalesGroup    Weight (g)  \
# 0    R-17284   2022 goose & Watermelon bull          N     97.573505
# 1    R-18292         Vegan Caesar wrap 2022          N    437.897042
# 2    R-15423          "Pulled Pork" Sliders          N    208.720500
# 3     R-6243            2019 Chipotle Aioli          N  32258.000000
# 4    R-13758           2019 Falafel Edamame          Y  29669.000000
# ..       ...                            ...        ...           ...
# 286  R-18272    Truffle Mushroom Pasta 2023          N    342.824999
# 287  R-15427            Vegan Chipotle Mayo          N   1150.000000
# 288  R-15426            Vegan Tofu Scramble          N     50.280000
# 289  R-15544                   VEGGIE BENNY          N    225.000000
# 290  R-18675     Veggie Burger Special 2023          N    294.544996
#
#      GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0           26.842002    0.183600        0.028850                        2.54
# 1          409.785901    3.392543        2.000068                       29.07
# 2         1054.955596   13.558082        2.451705                      210.91
# 3        70693.846600  429.368800       80.947380                      735.25
# 4        42505.028100  161.011300      177.832190                      363.29
# ..                ...         ...             ...                         ...
# 286       1539.977637    8.291102        2.927251                       84.69
# 287       9370.300000    7.762500       31.000000                       27.93
# 288         48.810812    0.339712        0.087333                        2.22
# 289        342.127000    1.802500        1.816600                       21.78
# 290        294.344507    2.229055        0.903210                       33.65
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 0                            90.18                    27.51
# 1                          1081.32                    93.58
# 2                          6351.04                   505.44
# 3                        330063.55                   219.15
# 4                         12654.87                   143.26
# ..                             ...                      ...
# 286                        5556.78                   449.20
# 287                         390.54                   814.81
# 288                          18.30                    97.08
# 289                         678.34                   152.06
# 290                        1149.94                    99.93
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 0                 0.19                               2.60
# 1                 0.77                               6.64
# 2                 6.50                             101.05
# 3                 1.33                               2.28
# 4                 0.54                               1.22
# ..                 ...                                ...
# 286               2.42                              24.70
# 287               0.68                               2.43
# 288               0.68                               4.42
# 289               0.80                               9.68
# 290               0.76                              11.42
#
#      Stress-Weighted Water Use (L) / 100g  Land Use (m^2) / 100g  \
# 0                                   92.42                   0.03
# 1                                  246.93                   0.46
# 2                                 3042.84                   1.17
# 3                                 1023.20                   0.25
# 4                                   42.65                   0.60
# ..                                    ...                    ...
# 286                               1620.88                   0.85
# 287                                 33.96                   2.70
# 288                                 36.40                   0.17
# 289                                301.48                   0.81
# 290                                390.41                   0.31
#
#     GHG Only Label
# 0            Green
# 1            Green
# 2              Red
# 3           Yellow
# 4            Green
# ..             ...
# 286            Red
# 287            Red
# 288          Green
# 289          Green
# 290          Green
#
# [291 rows x 15 columns]

# %%
final = create_results_all_factors(final)
final
# Out:
#       ProdId                    Description SalesGroup    Weight (g)  \
# 0    R-17284   2022 goose & Watermelon bull          N     97.573505
# 1    R-18292         Vegan Caesar wrap 2022          N    437.897042
# 2    R-15423          "Pulled Pork" Sliders          N    208.720500
# 3     R-6243            2019 Chipotle Aioli          N  32258.000000
# 4    R-13758           2019 Falafel Edamame          Y  29669.000000
# ..       ...                            ...        ...           ...
# 286  R-18272    Truffle Mushroom Pasta 2023          N    342.824999
# 287  R-15427            Vegan Chipotle Mayo          N   1150.000000
# 288  R-15426            Vegan Tofu Scramble          N     50.280000
# 289  R-15544                   VEGGIE BENNY          N    225.000000
# 290  R-18675     Veggie Burger Special 2023          N    294.544996
#
#      GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0           26.842002    0.183600        0.028850                        2.54
# 1          409.785901    3.392543        2.000068                       29.07
# 2         1054.955596   13.558082        2.451705                      210.91
# 3        70693.846600  429.368800       80.947380                      735.25
# 4        42505.028100  161.011300      177.832190                      363.29
# ..                ...         ...             ...                         ...
# 286       1539.977637    8.291102        2.927251                       84.69
# 287       9370.300000    7.762500       31.000000                       27.93
# 288         48.810812    0.339712        0.087333                        2.22
# 289        342.127000    1.802500        1.816600                       21.78
# 290        294.344507    2.229055        0.903210                       33.65
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 0                            90.18                    27.51
# 1                          1081.32                    93.58
# 2                          6351.04                   505.44
# 3                        330063.55                   219.15
# 4                         12654.87                   143.26
# ..                             ...                      ...
# 286                        5556.78                   449.20
# 287                         390.54                   814.81
# 288                          18.30                    97.08
# 289                         678.34                   152.06
# 290                        1149.94                    99.93
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 0                 0.19                               2.60
# 1                 0.77                               6.64
# 2                 6.50                             101.05
# 3                 1.33                               2.28
# 4                 0.54                               1.22
# ..                 ...                                ...
# 286               2.42                              24.70
# 287               0.68                               2.43
# 288               0.68                               4.42
# 289               0.80                               9.68
# 290               0.76                              11.42
#
#      Stress-Weighted Water Use (L) / 100g  Land Use (m^2) / 100g  \
# 0                                   92.42                   0.03
# 1                                  246.93                   0.46
# 2                                 3042.84                   1.17
# 3                                 1023.20                   0.25
# 4                                   42.65                   0.60
# ..                                    ...                    ...
# 286                               1620.88                   0.85
# 287                                 33.96                   2.70
# 288                                 36.40                   0.17
# 289                                301.48                   0.81
# 290                                390.41                   0.31
#
#     GHG Only Label Combined Label
# 0            Green          Green
# 1            Green          Green
# 2              Red            Red
# 3           Yellow         Yellow
# 4            Green          Green
# ..             ...            ...
# 286            Red            Red
# 287            Red            Red
# 288          Green          Green
# 289          Green          Green
# 290          Green          Green
#
# [291 rows x 16 columns]

# %%
final.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".csv", 
             index=False)
final.to_excel("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".xlsx", 
               sheet_name="Labels", index=False)

# %%
# CHANGE THE NAME AS NEEDED AS PER THE RESTAURANT:

OK_list = final.set_index('Description')['ProdId'].to_dict()
OK_list
# Out:
# {' 2022 goose & Watermelon bull': 'R-17284',
#  ' Vegan Caesar wrap 2022': 'R-18292',
#  '"Pulled Pork" Sliders': 'R-15423',
#  '2019 Chipotle Aioli': 'R-6243',
#  '2019 Falafel Edamame': 'R-13758',
#  '2019 Ginger Garlic Paste': 'R-13736',
#  '2019 Makhni Sauce': 'R-13737',
#  '2019 Organic Quinoa': 'R-13747',
#  '2022  BUTTERMILK TENDERS': 'R-14906',
#  '2022  Candied Pecans Batch': 'R-12613',
#  '2022  Extreme Nachos': 'R-16573',
#  '2022  FISH TACO': 'R-15511',
#  '2022 ADD ON 1 pcs fish ': 'R-10484',
#  '2022 Aglio e Olio (Chicken)': 'R-17356',
#  '2022 Ancho Tempeh marinade': 'R-16570',
#  '2022 Ancho Tempeh Taco': 'R-16576',
#  '2022 Apple crisp': 'R-17377',
#  '2022 Appy Platter': 'R-16775',
#  '2022 artichoke dip': 'R-16016',
#  '2022 Beef Gravy': 'R-17360',
#  '2022 Black Olive Hummus': 'R-13937',
#  '2022 Blackened Chicken': 'R-17486',
#  '2022 blackened salmon seasonin': 'R-16833',
#  '2022 Blackned Salmon ': 'R-16789',
#  '2022 Blackning Spice': 'R-16787',
#  '2022 braised pork ribs': 'R-17374',
#  '2022 Brussel sprout ': 'R-17354',
#  '2022 cajun chicken taco': 'R-16099',
#  '2022 Calamari ': 'R-14990',
#  '2022 Candied Walnut': 'R-16778',
#  '2022 Carbonara Sauce': 'R-12209',
#  '2022 Cauliflower Taco': 'R-14827',
#  '2022 Chicken Caesar': 'R-8990',
#  '2022 Chicken for KFC': 'R-16581',
#  '2022 Chicken Marinate': 'R-16748',
#  '2022 chicken pesto marination': 'R-17014',
#  "2022 CHICKEN PO'BOY ": 'R-10589',
#  '2022 chicken tenders marinate': 'R-17037',
#  '2022 chilli oil': 'R-16217',
#  '2022 Coleslaw mix': 'R-14715',
#  '2022 compressed watermelon': 'R-17027',
#  '2022 Corn Fritters batter': 'R-17314',
#  '2022 Corn Fritters. ': 'R-17369',
#  '2022 Cranberry Vinaigrette ': 'R-17352',
#  '2022 Crispy Cauliflower ': 'R-14981',
#  '2022 El diablo Seas': 'R-16760',
#  '2022 fried chick pea': 'R-17378',
#  '2022 Fried Chicken Tenders ': 'R-14905',
#  '2022 Fried Chicken Thigh': 'R-11631',
#  '2022 Gallery Fries': 'R-9017',
#  '2022 Gallery Nacho Xtream': 'R-15449',
#  '2022 Gallery Nachos': 'R-14525',
#  '2022 Garlic confit': 'R-16855',
#  '2022 Glass Noodle Salad': 'R-14507',
#  '2022 green pea and green onion': 'R-14271',
#  '2022 Green Thai Curry': 'R-15438',
#  '2022 Gretest Gallery Burger': 'R-16791',
#  '2022 Grilled Peach Salsa': 'R-16574',
#  '2022 Grilled Peach Salsa2': 'R-17039',
#  '2022 Grilled Pineapple': 'R-16794',
#  '2022 ground beef': 'R-16773',
#  '2022 Group Appi Platter': 'R-16831',
#  '2022 Harvest - Salad': 'R-17371',
#  '2022 Herb oil': 'R-17013',
#  '2022 herb tahini dressing': 'R-16834',
#  '2022 HH Brussels Sprouts': 'R-17304',
#  '2022 HH Chips & Salsa': 'R-17302',
#  '2022 HH Corn Fritters': 'R-17316',
#  '2022 HH fried Gyoza': 'R-17301',
#  '2022 HH Gallery Fries': 'R-15047',
#  '2022 HH Hummus & pita': 'R-17306',
#  '2022 HH onion ring': 'R-9016',
#  '2022 HH Poutine': 'R-17300',
#  '2022 HH Quesadilla': 'R-15173',
#  '2022 HH Spring Rolls': 'R-17303',
#  '2022 hot salsa': 'R-16218',
#  '2022 house dressing': 'R-16857',
#  '2022 Jasmin rice': 'R-15477',
#  '2022 KFC Flour Batter': 'R-16580',
#  '2022 KFC Sauce': 'R-16579',
#  '2022 Lemon & pepper seasoning': 'R-17026',
#  '2022 lemon and pepper': 'R-16863',
#  '2022 Lime Aioli ': 'R-16575',
#  '2022 Mashed potato': 'R-16843',
#  '2022 memphis spice': 'R-16864',
#  '2022 Miso Carbonara Sauce': 'R-16582',
#  '2022 Mushroom Burger': 'R-15050',
#  '2022 peach salsa': 'R-17028',
#  '2022 Pesto ': 'R-14885',
#  '2022 Pickle onion': 'R-16572',
#  '2022 pickled jalapeno': 'R-16221',
#  '2022 pickled jalepenos': 'R-16223',
#  '2022 Pickled Onion2': 'R-17040',
#  '2022 pickled onions ': 'R-16222',
#  '2022 pickling liquid': 'R-16571',
#  '2022 Pico De Gallo ': 'R-11125',
#  "2022 po' boy slaw": 'R-16106',
#  '2022 Pork Gyoza ': 'R-15417',
#  '2022 pork taco': 'R-17126',
#  '2022 Pulao': 'R-14692',
#  '2022 Quinoa Croquette': 'R-16785',
#  '2022 Quinoa Puffed': 'R-16786',
#  '2022 Quinoa Salad': 'R-16783',
#  '2022 Roasted Carrots': 'R-16784',
#  '2022 roasted pork': 'R-16861',
#  '2022 roasted tri color carrots': 'R-16835',
#  '2022 Salmon Carbonara': 'R-16798',
#  '2022 Salmon Teriyaki': 'R-16585',
#  '2022 schezwan Tempeh': 'R-14983',
#  '2022 sheperds Pie filing': 'R-17373',
#  '2022 simlpe syrup': 'R-16859',
#  '2022 simple syrup': 'R-16844',
#  '2022 slaw dressing': 'R-16860',
#  '2022 Sriracha mayo': 'R-16862',
#  '2022 Sub House salad': 'R-8988',
#  '2022 Sweet chili (chicken)': 'R-17362',
#  '2022 Sweet chili (Tofu)': 'R-17363',
#  '2022 sweet chili Sauce Gallery': 'R-17350',
#  '2022 Sweet soy Glaze (Gallery)': 'R-17353',
#  '2022 Tahini Dressing': 'R-14504',
#  '2022 tex mex burger': 'R-16006',
#  '2022 To go Cutlery': 'R-17297',
#  '2022 Truffle Fries': 'R-14987',
#  '2022 Vegan Burger': 'R-15057',
#  '2022 Vegan Caesar dressing': 'R-16780',
#  '2022 Vegan Caesar Salad': 'R-16782',
#  '2022 vegan crema': 'R-16858',
#  '2022 vegan croutons': 'R-16856',
#  '2022 Waffle - Chix': 'R-15405',
#  '2022 Waffle Pulled Pork': 'R-16801',
#  '2022 Waffle Vegan Chix': 'R-16802',
#  '2022 Watermelon dressing': 'R-16777',
#  '2022 Watermelon Salad': 'R-16776',
#  '2023 Chicken Tikka': 'R-15038',
#  '2023 GM Appi Platter': 'R-18412',
#  '2023 GM marinated Olives': 'R-18470',
#  '2023 GM Pesto Penne': 'R-18344',
#  '2023 group cheese platter': 'R-16832',
#  '2023 Hh Babaganoush': 'R-18403',
#  '2023 HH Chick pea Falafel ': 'R-18342',
#  '2023 HH Fries': 'R-18341',
#  '2023 Homemade burger 5oz': 'R-18459',
#  '2023 Sub Sweet potato fries pr': 'R-18359',
#  '2023 Tzatziki gallery': 'R-5816',
#  'a': 'R-18277',
#  'Aloo Puri 2022': 'R-16355',
#  'Aperol Spritz Tap': 'R-12290',
#  'b': 'R-18271',
#  'Bellini Tap': 'R-11289',
#  'BIB Mix Coke': 'R-13395',
#  'BIB Mix Coke Zero': 'R-13396',
#  'BIB Mix Ginger Ale': 'R-13397',
#  'BIB Mix Iced Tea': 'R-13399',
#  'BIB Mix Sprite': 'R-13398',
#  'BIB Mix Tonic': 'R-13402',
#  'Blkn Carbonara 2023': 'R-18310',
#  'BQT Mushroom Mix': 'R-14150',
#  'BYO "PULLED PORK" TACO ': 'R-15512',
#  'BYO CAULIFLOWER TACO': 'R-15510',
#  'c': 'R-17988',
#  'Chick pea Falafel Gallery 2023': 'R-18265',
#  'Chicken Pesto Marinate 2023 ': 'R-18334',
#  'chicken Tender': 'R-15139',
#  'Cinnamon Sugar': 'R-6160',
#  'Cold Brew Batch': 'R-13514',
#  'Cooked Linguini 2023': 'R-18349',
#  'Cucumber Marinate Gal.': 'R-16994',
#  'Flat Bread (vegan)2023': 'R-18267',
#  'Flat Bread chorizo 2023': 'R-18269',
#  'Flat Bread Funghi 2023': 'R-18270',
#  'Fresh Lemonade': 'R-13394',
#  'G18 Java Rice': 'R-12034',
#  'G18 Parmesan Aioli': 'R-12266',
#  'G19 Tomato Pesto': 'R-13708',
#  'G20 Chicken Tenders': 'R-14893',
#  'G20 Fresh Iced Tea': 'R-14093',
#  'G20 Grilled Cheese ': 'R-14818',
#  'G20 gyoza': 'R-14347',
#  'G20 Hummus ': 'R-14296',
#  'G20 Hummus & Naan': 'R-14480',
#  'G20 Individual Cheese Plate': 'R-14152',
#  'G20 Korma': 'R-14689',
#  'G20 Mediteranean Platter': 'R-14096',
#  'G20 Pickles': 'R-14346',
#  'G20 Pierogi': 'R-14623',
#  'G20 Refried Bean Spread': 'R-14826',
#  'G20 Roasted Chickpeas Coating': 'R-14529',
#  'G21 Avocado Spread': 'R-15407',
#  'G21 AVOCADO TOAST': 'R-15408',
#  'G21 B,Bean Patty': 'R-15486',
#  'G21 BBQ Burger': 'R-15053',
#  'G21 BLT': 'R-15403',
#  'G21 BREAKFAST TACO': 'R-15411',
#  'G21 Calamari Flour': 'R-15024',
#  'G21 Cheesecake': 'R-15431',
#  'G21 Chicken Tikka': 'R-15018',
#  'G21 Chili Oil': 'R-14985',
#  'G21 Chipotle Cilantro': 'R-14995',
#  'G21 Clarified Buttter': 'R-15505',
#  'G21 Creole Dressing': 'R-15073',
#  'G21 Eggs Benny': 'R-15434',
#  'G21 Gal BUTTERMILK WINGS': 'R-14997',
#  'G21 Gallery Breakfast': 'R-15414',
#  'G21 Green Goddess Dressing': 'R-15010',
#  'G21 Grilled Wings Marinade': 'R-15012',
#  'G21 Herb Mix': 'R-14988',
#  'G21 Hollandaise ': 'R-15433',
#  'G21 Honey Cayenne Mayo': 'R-15401',
#  'G21 Honey Lemon Vinaigrette': 'R-15400',
#  'G21 Ice Cream Sandwich': 'R-15429',
#  'G21 Mac And Cheese': 'R-15017',
#  'G21 Mango Habanero': 'R-14992',
#  'G21 Meatballs': 'R-15065',
#  'G21 Pickled Red Cabbage': 'R-15412',
#  'G21 Poached Egg': 'R-15409',
#  'G21 Raspberry Vinaigrette': 'R-15402',
#  'G21 Roasted Broccoli': 'R-15008',
#  'G21 Roasted Cauliflower ': 'R-15007',
#  'G21 Roasted Portobello': 'R-15051',
#  'G21 Sesame Black Vin': 'R-15418',
#  'G21 Sesame Sweet Soy ': 'R-15001',
#  'G21 SIDE HASH': 'R-15488',
#  'G21 Southwest Tofu Scrambled ': 'R-15425',
#  'G21 Spaghetti Meatballs': 'R-15075',
#  'G21 SUMMER SALAD': 'R-15436',
#  'G21 Teriyaki Sauce ': 'R-14984',
#  'G21 Ultimate Burger': 'R-15055',
#  'Gallery Cauliflower Coating': 'R-14735',
#  'Gallery Mimosa': 'R-14823',
#  'Gallery Sundae': 'R-14250',
#  'Garlic Baguette Slice': 'R-12306',
#  "GLRY CHICKEN PO' BOY": 'R-9389',
#  'Glry Side Fries 2023': 'R-11706',
#  'Green Goddess Dressing 2022': 'R-16061',
#  'Gremolata 2022': 'R-18348',
#  'HH FISH TACO': 'R-15342',
#  'Honey Ginger Syrup': 'R-13015',
#  'HONOURROLL PLATTER': 'R-14594',
#  'Hot Apple Cider Batch': 'R-11361',
#  'HR AVOCADO ROLL': 'R-13957',
#  'HR HARU TRAY(VEGE)': 'R-14584',
#  'HR MANGO CRUNCH ROLL': 'R-14586',
#  'linguini': 'R-13414',
#  'M/O Special Squid 2023': 'R-18720',
#  'Marinara Sauce': 'R-15368',
#  'Monthly special Perogies (nov)': 'R-18895',
#  'Mulled Wine Batch': 'R-11360',
#  'NEW CURRY LENTAL RICE BOWL': 'R-11824',
#  'NEW FISH BATTER MIX': 'R-9013',
#  'NEW PIT CAESAR SALAD SIDE': 'R-8992',
#  'NEW PIT GREEN SALAD': 'R-8987',
#  'NEW ROAST PEPPERS': 'R-11408',
#  'NEW Steamed Rice': 'R-5674',
#  'nigiri ebi': 'R-14342',
#  'NIGIRI INARI': 'R-14390',
#  'nigiri rice ': 'R-14339',
#  'nigiri salmon': 'R-14340',
#  'nigiri tamago': 'R-14400',
#  'nigiri tuna': 'R-14341',
#  'NOBASHI TEMPURA': 'R-17134',
#  'Orange Vinaigrette 2023': 'R-18274',
#  'PICNIC Mac&Cheese Meal': 'R-15513',
#  'Porch - Yellow Curry': 'R-17941',
#  'Porch Dressing Asian Sesame': 'R-14665',
#  'Porch Roasted Red onion': 'R-14723',
#  'Porch Roasted Yellow Pepper': 'R-14726',
#  'Porch Roasted Zuccuhini': 'R-14719',
#  'Porch Tomato Chipotle Soup': 'R-7814',
#  'proposed change to sangria': 'R-15838',
#  'Puttanesca sauce (special 2023': 'R-17987',
#  'Puttanesca Sauce M/o Special': 'R-18719',
#  'rice vinegar': 'R-12339',
#  'roasted baby carrots': 'R-16701',
#  'Roasted mix veggie 2023': 'R-18268',
#  'Rose Sangria Tap 2022': 'R-16654',
#  'Sangria Red Tap 2022 TBD': 'R-11285',
#  'Sangria White Tap 2022 TBD': 'R-11439',
#  'Sesame Ginger Soy Dressing': 'R-14506',
#  'Simple Syrup': 'R-7119',
#  'Soda Water': 'R-13392',
#  'Spicy marinara sauce 2023': 'R-18317',
#  'Sub-Caesar Salad': 'R-15180',
#  'Sushi Rice': 'R-13956',
#  'Sushi Su': 'R-13955',
#  'Tikka Marinade for chicken Gal': 'R-15037',
#  'TOGO ': 'R-15315',
#  'Truffle Mushroom Pasta 2023': 'R-18272',
#  'Vegan Chipotle Mayo': 'R-15427',
#  'Vegan Tofu Scramble': 'R-15426',
#  'VEGGIE BENNY': 'R-15544',
#  'Veggie Burger Special 2023': 'R-18675'}

# %%
final2 = final.copy()
final2 = add_menu_names(final, OK_list)
final2.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.csv",
                  index=False)
final2.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.xlsx",
                  index=False)

# %%
# # # ADDED FOR GATHER:
# final2 = pd.read_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.csv")
# final2.head()
# Out:
#                          Category Displayed Name   ProdId  \
# 0  $1 OWN MUG ETHICAL BEAN COFFEE            NaN  R-67294
# 1                         ADD CUP            NaN  R-62976
# 2                             ADD           Beef  R-31006
# 3                             ADD        Chicken  R-31131
# 4                             ADD       Crackers  R-30154
#
#                       Description           SalesGroup  Weight (g)  \
# 0  $1 OWN MUG ETHICAL BEAN COFFEE             BEVERAGE    386.0000
# 1                         ADD CUP       OK - GRAB & GO      1.0000
# 2                        ADD|Beef  OK - CUSTOM KITCHEN     85.0485
# 3                     ADD|Chicken  OK - CUSTOM KITCHEN     85.0485
# 4                    ADD|Crackers  OK - CUSTOM KITCHEN      6.0000
#
#    GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0        911.741955    0.743803        0.000000                        4.29
# 1          0.000000    0.000000        0.000000                        0.00
# 2       3516.440796   28.023481       10.754383                      142.64
# 3        468.387687   12.417476        1.225451                       39.37
# 4          9.135000    0.088800        0.029340                        2.52
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                         571.66                   236.20               0.19
# 1                           0.00                     0.00               0.00
# 2                        5214.24                  4134.63              32.95
# 3                          35.47                   550.73              14.60
# 4                          76.93                   152.25               1.48
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               1.11                                148.10
# 1                               0.00                                  0.00
# 2                             167.72                               6130.90
# 3                              46.29                                 41.71
# 4                              42.00                               1282.17
#
#    Land Use (m^2) / 100g GHG Only Label Combined Label
# 0                   0.00         Yellow          Green
# 1                   0.00          Green          Green
# 2                  12.64            Red            Red
# 3                   1.44            Red            Red
# 4                   0.49          Green         Yellow

# %%
counts = create_final_counts(final2)
all_ghg_num = counts["GHG Label Counts"].sum()
all_num = counts["Combined Label Counts"].sum()
sum_row = pd.Series(data={"GHG Label Counts": all_ghg_num, "Combined Label Counts": all_num}, name="Sum")
# Out:
# 76 64 148

# %%
counts = counts.append(sum_row, ignore_index=False)
counts.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/"+restaurant_name+"_Summary.csv", index=False)
counts_print = pd.concat([counts, sum_row], ignore_index=True)
counts


# THERE ARE 5 SUM ROWS BECUASE THERE ARE 5 EMISSION FACTORS THAT WE ARE LOOKING AT: GHG, nitrogen, stressed water, fresh water
# and land use
# Out:
# C:\Users\smvan\AppData\Local\Temp\ipykernel_19532\3944149530.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   counts = counts.append(sum_row, ignore_index=False)
#         GHG Label Counts  Combined Label Counts
# Red                   76                     76
# Yellow                66                     64
# Green                146                    148
# Sum                  288                    288

# %%
# THE BLUE BAR REPRESENTS THE SUM ROW WHICH IS THE TOTAL NUMBER OF RECIPES THAT HAVE BEEN ASSIGNED A LABEL
# EACH BAR REPRESENTS THE # OF RECIPES THAT WERE LABELLED WITH THAT SPECIFIC COLOUR

fig = create_visualizations(counts)
fig

# %%
final2.head()
# Out:
#                         Category Displayed Name   ProdId  \
# 0   2022 goose & Watermelon bull                 R-17284
# 1         Vegan Caesar wrap 2022                 R-18292
# 2          "Pulled Pork" Sliders                 R-15423
# 3            2019 Chipotle Aioli                  R-6243
# 4           2019 Falafel Edamame                 R-13758
#
#                      Description SalesGroup    Weight (g)  GHG Emission (g)  \
# 0   2022 goose & Watermelon bull          N     97.573505         26.842002
# 1         Vegan Caesar wrap 2022          N    437.897042        409.785901
# 2          "Pulled Pork" Sliders          N    208.720500       1054.955596
# 3            2019 Chipotle Aioli          N  32258.000000      70693.846600
# 4           2019 Falafel Edamame          Y  29669.000000      42505.028100
#
#    N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0    0.183600        0.028850                        2.54
# 1    3.392543        2.000068                       29.07
# 2   13.558082        2.451705                      210.91
# 3  429.368800       80.947380                      735.25
# 4  161.011300      177.832190                      363.29
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                          90.18                    27.51               0.19
# 1                        1081.32                    93.58               0.77
# 2                        6351.04                   505.44               6.50
# 3                      330063.55                   219.15               1.33
# 4                       12654.87                   143.26               0.54
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               2.60                                 92.42
# 1                               6.64                                246.93
# 2                             101.05                               3042.84
# 3                               2.28                               1023.20
# 4                               1.22                                 42.65
#
#    Land Use (m^2) / 100g GHG Only Label Combined Label
# 0                   0.03          Green          Green
# 1                   0.46          Green          Green
# 2                   1.17            Red            Red
# 3                   0.25         Yellow         Yellow
# 4                   0.60          Green          Green

# %%
final3 = final2.drop(columns=['Category', 'Displayed Name', 'Weight (g)', 'GHG Only Label'])

# %%
final3.head()
# Out:
#     ProdId                    Description SalesGroup  GHG Emission (g)  \
# 0  R-17284   2022 goose & Watermelon bull          N         26.842002
# 1  R-18292         Vegan Caesar wrap 2022          N        409.785901
# 2  R-15423          "Pulled Pork" Sliders          N       1054.955596
# 3   R-6243            2019 Chipotle Aioli          N      70693.846600
# 4  R-13758           2019 Falafel Edamame          Y      42505.028100
#
#    N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0    0.183600        0.028850                        2.54
# 1    3.392543        2.000068                       29.07
# 2   13.558082        2.451705                      210.91
# 3  429.368800       80.947380                      735.25
# 4  161.011300      177.832190                      363.29
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                          90.18                    27.51               0.19
# 1                        1081.32                    93.58               0.77
# 2                        6351.04                   505.44               6.50
# 3                      330063.55                   219.15               1.33
# 4                       12654.87                   143.26               0.54
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               2.60                                 92.42
# 1                               6.64                                246.93
# 2                             101.05                               3042.84
# 3                               2.28                               1023.20
# 4                               1.22                                 42.65
#
#    Land Use (m^2) / 100g Combined Label
# 0                   0.03          Green
# 1                   0.46          Green
# 2                   1.17            Red
# 3                   0.25         Yellow
# 4                   0.60          Green

# %%
final3.rename(columns={'ProdId': 'Optimum Control ID', 'Description': 'OC Description'}, inplace=True)

# %%
final3.head()
# Out:
#   Optimum Control ID                 OC Description SalesGroup  \
# 0            R-17284   2022 goose & Watermelon bull          N
# 1            R-18292         Vegan Caesar wrap 2022          N
# 2            R-15423          "Pulled Pork" Sliders          N
# 3             R-6243            2019 Chipotle Aioli          N
# 4            R-13758           2019 Falafel Edamame          Y
#
#    GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0         26.842002    0.183600        0.028850                        2.54
# 1        409.785901    3.392543        2.000068                       29.07
# 2       1054.955596   13.558082        2.451705                      210.91
# 3      70693.846600  429.368800       80.947380                      735.25
# 4      42505.028100  161.011300      177.832190                      363.29
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                          90.18                    27.51               0.19
# 1                        1081.32                    93.58               0.77
# 2                        6351.04                   505.44               6.50
# 3                      330063.55                   219.15               1.33
# 4                       12654.87                   143.26               0.54
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               2.60                                 92.42
# 1                               6.64                                246.93
# 2                             101.05                               3042.84
# 3                               2.28                               1023.20
# 4                               1.22                                 42.65
#
#    Land Use (m^2) / 100g Combined Label
# 0                   0.03          Green
# 1                   0.46          Green
# 2                   1.17            Red
# 3                   0.25         Yellow
# 4                   0.60          Green

# %%
final3['Red'] = final3['Combined Label'] == 'Red'
final3['Yellow'] = final3['Combined Label'] == 'Yellow'
final3['Green'] = final3['Combined Label'] == 'Green'

# %%
final3.head()
# Out:
#   Optimum Control ID                 OC Description SalesGroup  \
# 0            R-17284   2022 goose & Watermelon bull          N
# 1            R-18292         Vegan Caesar wrap 2022          N
# 2            R-15423          "Pulled Pork" Sliders          N
# 3             R-6243            2019 Chipotle Aioli          N
# 4            R-13758           2019 Falafel Edamame          Y
#
#    GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0         26.842002    0.183600        0.028850                        2.54
# 1        409.785901    3.392543        2.000068                       29.07
# 2       1054.955596   13.558082        2.451705                      210.91
# 3      70693.846600  429.368800       80.947380                      735.25
# 4      42505.028100  161.011300      177.832190                      363.29
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                          90.18                    27.51               0.19
# 1                        1081.32                    93.58               0.77
# 2                        6351.04                   505.44               6.50
# 3                      330063.55                   219.15               1.33
# 4                       12654.87                   143.26               0.54
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               2.60                                 92.42
# 1                               6.64                                246.93
# 2                             101.05                               3042.84
# 3                               2.28                               1023.20
# 4                               1.22                                 42.65
#
#    Land Use (m^2) / 100g Combined Label    Red  Yellow  Green
# 0                   0.03          Green  False   False   True
# 1                   0.46          Green  False   False   True
# 2                   1.17            Red   True   False  False
# 3                   0.25         Yellow  False    True  False
# 4                   0.60          Green  False   False   True

# %%
import pandas as pd


desired_column_order = [
    'Optimum Control ID', 'OC Description', 'SalesGroup', 'Combined Label', 'Red', 'Yellow', 'Green',
    'GHG Emission (g)', 'N lost (g)', 'Land Use (m^2)', 'Freshwater Withdrawals (L)', 
    'Stress-Weighted Water Use (L)', 'GHG Emission (g) / 100g', 'N lost (g) / 100g', 
    'Freshwater Withdrawals (L) / 100g', 'Stress-Weighted Water Use (L) / 100g', 
    'Land Use (m^2) / 100g'
]

# Create a new DataFrame with the desired column order
data_reordered = final3[desired_column_order]

# Print the reordered DataFrame
data_reordered.head()
# Out:
#   Optimum Control ID                 OC Description SalesGroup Combined Label  \
# 0            R-17284   2022 goose & Watermelon bull          N          Green
# 1            R-18292         Vegan Caesar wrap 2022          N          Green
# 2            R-15423          "Pulled Pork" Sliders          N            Red
# 3             R-6243            2019 Chipotle Aioli          N         Yellow
# 4            R-13758           2019 Falafel Edamame          Y          Green
#
#      Red  Yellow  Green  GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 0  False   False   True         26.842002    0.183600        0.028850
# 1  False   False   True        409.785901    3.392543        2.000068
# 2   True   False  False       1054.955596   13.558082        2.451705
# 3  False    True  False      70693.846600  429.368800       80.947380
# 4  False   False   True      42505.028100  161.011300      177.832190
#
#    Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                        2.54                          90.18
# 1                       29.07                        1081.32
# 2                      210.91                        6351.04
# 3                      735.25                      330063.55
# 4                      363.29                       12654.87
#
#    GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                    27.51               0.19
# 1                    93.58               0.77
# 2                   505.44               6.50
# 3                   219.15               1.33
# 4                   143.26               0.54
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               2.60                                 92.42
# 1                               6.64                                246.93
# 2                             101.05                               3042.84
# 3                               2.28                               1023.20
# 4                               1.22                                 42.65
#
#    Land Use (m^2) / 100g
# 0                   0.03
# 1                   0.46
# 2                   1.17
# 3                   0.25
# 4                   0.60

# %%
data_reordered.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Labelled_Data_"+restaurant_name+"_for_nutrislice.csv",
                  index=False)
