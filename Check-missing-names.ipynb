# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_Gather22-23_with_name.csv")
df.head(50)
# Out:
#           Category                 Displayed Name   ProdId  \
# 0        Grill PM                   Poutine Gravy  R-44765
# 1        Grill PM     TMRW mushroom crunch burger  R-64698
# 2        Grill PM           Fish Fritters & chips  R-61978
# 3        Grill PM             Kimchi Bacon burger  R-56157
# 4        Grill PM               Lumberjack Burger  R-44655
# 5        Grill PM                   Alumni burger  R-68378
# 6        Grill PM             Bacon cheese burger  R-36098
# 7        Grill PM            Planetary BBQ burger  R-65248
# 8        Grill PM          Planetary Greek Burger  R-69135
# 9        Grill PM           Jerk Jackfruit burger  R-53579
# 10       Grill PM               Portobello Burger  R-61830
# 11       Grill PM                   Salmon burger  R-44931
# 12       Grill PM               Cauliflower Bites  R-61982
# 13       Grill PM            Cajun chicken burger  R-55469
# 14       Grill PM    Guac, bacon + chicken burger  R-28251
# ...

# %%
df[df['Category'].isna()]
# Out:
#     Category Displayed Name   ProdId                     Description  \
# 106      NaN            NaN  R-54557        FLX|GLB|Garlic Flatbread
# 116      NaN            NaN  R-44885    FLX|Bao Shitake & Kimchi|AAD
# 119      NaN            NaN  R-61970            FLX|Bao|Mushroom|AAD
# 142      NaN            NaN  R-62054              SL|Beef Brisket|+3
# 185      NaN            NaN  R-62302              SL|Sauce|RATIO|NEW
# 186      NaN            NaN  R-57243         SL|Side|beans and pesto
# 187      NaN            NaN  R-37868           SL|Side|Beans Romano
# 188      NaN            NaN  R-44814            SL|Side|Potato baked
# 189      NaN            NaN  R-36874   SL|Side|Potato Rosemary Roast
# 190      NaN            NaN  R-47746  SL|Side|Potato Smash Olive Oil
# 191      NaN            NaN  R-46330                  SL|Side|Quinoa
# 192      NaN            NaN  R-36854              SL|Side|Rice Brown
# 193      NaN            NaN  R-52652          SL|Side|Roasted Potato
# ...

# %%
df["Category"].unique()
# Out:
# array(['Grill PM ', 'Grill AM ', 'Fresh Fare AM ', 'Fresh Fare PM ', nan,
#        'Home Cooking ', 'Simply Local ', 'Caliente ', 'Gyaza '],
#       dtype=object)

# %%
df[df["Displayed Name"].isnull()]
# Out:
#     Category Displayed Name   ProdId               Description  \
# 106      NaN            NaN  R-54557  FLX|GLB|Garlic Flatbread
#
#               SalesGroup  Weight (g)  GHG Emission (g)  N lost (g)  \
# 106  GV FLEX GLOBAL BOWL   35.208334          87.73544    0.830537
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 106                       16.45                         569.89
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 106                   249.19               2.36
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 106                              46.72                               1618.62
#
#     GHG Only Label Combined Label
# 106         Yellow         Yellow

# %%
df2 = df["Displayed Name"].str.split("|", n=1, expand=True)
df["Category"] = df2[0]
df["Displayed Name"] = df2[1]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 3>()
#       1 df2 = df["Displayed Name"].str.split("|", n=1, expand=True)
#       2 df["Category"] = df2[0]
# ----> 3 df["Displayed Name"] = df2[1]
#       4 df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# ...

# %%
ingre = pd.read_csv("data/preprocessed/Ingredients_List.csv")
ingre
# Out:
#     IngredientId      Qty   Uom  Conversion  InvFactor   Recipe
# 0         I-3643   225.00     g     0.00100     0.1837  P-18907
# 1         I-6026  1000.00     g     1.00000     0.8163  P-18907
# 2         I-6807     2.27    Kg     2.20462     1.4188  P-19175
# 3         I-4698    10.00    Kg     4.00000     1.3514  P-20239
# 4         I-4381     1.00    lb     1.00000     1.1111  P-24452
# ..           ...      ...   ...         ...        ...      ...
# 498      I-15032     0.15  LOAF     1.00000     1.0000  R-69126
# 499       I-2156    40.00     g     0.00100     1.0000  R-69126
# 500       I-3625     1.00     g     1.00000     1.0000  R-69126
# 501       I-8060    10.00     g     1.00000     1.0000  R-69126
# 502      P-64884    30.00     g     0.00100     1.0000  R-69126
#
# [503 rows x 6 columns]

# %%
ingre.loc[ingre["IngredientId"] == "I-3387"]
# Out:
#     IngredientId    Qty Uom  Conversion  InvFactor   Recipe
# 78        I-3387   0.32   L       1.000     0.4161  P-35251
# 132       I-3387  30.00  ml       0.001    18.7500  P-44913
# 158       I-3387   5.00  ml       0.001   100.0000  P-50231
# 162       I-3387  35.00  ml       0.001     3.5000  P-50287
# 170       I-3387  50.00  ml       0.001     5.0000  P-50288
# 174       I-3387  30.00  ml       0.001     0.3000  P-50289
# 225       I-3387  50.00  ml       0.001     1.1364  P-51382
# 253       I-3387  75.00  ml       0.001   100.0000  P-56778
# 260       I-3387  15.00  ml       0.001     0.0182  P-56923
# 309       I-3387   1.50   L       1.000     0.7500   P-7139
# 311       I-3387   1.00   L       1.000     0.2500   P-7444
# 322       I-3387   4.00   L       1.000     1.0000   P-9519

# %%
items = pd.read_csv("data/preprocessed/Items_List.csv")
items
# Out:
#       ItemId                    Description  CaseQty CaseUOM   PakQty PakUOM  \
# 0     I-3617        ALLSPICE GROUND SHAKER       8.0    each  454.000      g
# 1     I-4472                     AVOCADO MX     20.0      CT    1.000     CT
# 2     I-4973            AVOCADO PULP CHUNKY      6.0    each  907.185      g
# 3    I-65741     BACON 2.5MM NATURALLY SMKD      5.0      Kg    1.000     Kg
# 4    I-27410       BACON 3MM NATURALLY SMKD      5.0      Kg    1.000     Kg
# ..       ...                            ...      ...     ...      ...    ...
# 431   I-4927  TOMATOES CHERRY LOOSE CLAM BC     12.0     pak  340.000      g
# 432  I-17047    TUNA  ALBACORE LOIN MED MSC      1.0      lb    1.000     lb
# 433  I-29019      TUNA FLAKES DRIED BONITO       6.0     bag  500.000      g
# 434  I-40436           UMAMI DUST SEASONING      1.0    each  454.000      g
# 435   I-3697           VINEGAR SHERRY JEREZ      5.0       L    1.000      L
#
#      InventoryGroup
# 0            SPICES
# ...

# %%
items.loc[items["ItemId"] == "I-28914"]
# Out:
#       ItemId      Description  CaseQty CaseUOM  PakQty PakUOM  InventoryGroup
# 408  I-28914  GYOZA VEGETABLE    400.0      ea     1.0   each  FOOD - GROCERY
