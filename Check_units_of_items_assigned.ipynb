# %%
import pandas as pd
import numpy as np

# %%
Items_List_Assigned = pd.read_csv('C:/Users/smvan/CFFS-S23/CFFS-22-23/data/mapping/Items_List_Assigned.csv')
Items_List_Assigned.head()
# Out:
#     ItemId  CategoryID               Description  CaseQty CaseUOM  PakQty  \
# 0  I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1  I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2   I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3  I-37005         1.0            BEEF MEATBALLS     4.54      Kg  1000.0
# 4  I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
#
#   PakUOM InventoryGroup
# 0     Kg           MEAT
# 1     Kg           MEAT
# 2     Kg           MEAT
# 3      g           MEAT
# 4      g           MEAT

# %%
Conversions = pd.read_csv('C:/Users/smvan/CFFS-S23/CFFS-22-23/data/cleaning/Conversions_Added.csv')
Conversions = Conversions.dropna(subset=['ConversionId'], axis=0)
Conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 37        I-1041    1.000000             1.0             CT           1.0
# 38        I-1100    1.000000             1.0             CT           1.0
# 39        I-1122    0.014286             1.0             CT          70.0
# 40        I-1197    0.013333             1.0             CT          75.0
# 41        I-1274    1.000000             1.0           LOAF           1.0
# ..           ...         ...             ...            ...           ...
# 749      I-25290    0.000213             0.1           LOAF         470.0
# 750       I-9641    0.017544             1.0           LOAF          57.0
# 751      I-14190    0.001667             1.0           LOAF         600.0
# 752      I-37113    0.004274             1.0             ea         234.0
# 753       I-1271    0.000111             0.1           LOAF         900.0
#
#     ConvertToUom
# 37           bag
# 38             g
# 39             g
# ...

# %%
Not_in_items_list_assign = pd.DataFrame(columns=Items_List_Assigned.columns)

# give all rows in Items_List_Assigned that has a value from 'ConversionId' column that is not part of Conversions dataframe



unique_conversion_ids = Conversions['ConversionId'].unique()
rows_not_in_conversions = Items_List_Assigned[~Items_List_Assigned['ItemId'].isin(unique_conversion_ids)]
rows_not_in_conversions
# Out:
#        ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0     I-57545         1.0         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1     I-10869         1.0             BEEF STIRFRY COV FR     5.00      Kg
# 2      I-7064         1.0           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3     I-37005         1.0                  BEEF MEATBALLS     4.54      Kg
# 4     I-37002         1.0        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...       ...         ...                             ...      ...     ...
# 2816  I-17622        24.0         WAFFLES BLUBRRY - GF/WF    12.00     box
# 2817  I-45754        55.0        WATER ACTIVE LEMON LIME     12.00   450ML
# 2818  I-45755        55.0       WATER ACTIVE ORANGE MANGO    12.00   450ML
# 2819  I-45756        55.0  WATER ACTIVE STRAWB BLK CHERRY    12.00   450ML
# 2820  I-43251        55.0    WATER FRUIT 500ML PINEAPPLE     12.00   500ML
#
#       PakQty  PakUOM  InventoryGroup
# ...

# %%
# path = "C:/Users/smvan/CFFS-S23/CFFS-22-23"
# # path = os.getcwd()

# # os.chdir is used to change the current directory to the specified path
# os.chdir(path)
# path = os.path.join(os.getcwd(), "data", "preprocessed", "Conversions_List.csv")
# Conversions.to_csv(path, index = False, header = True)

rows_not_in_conversions.to_csv('C:/Users/smvan/CFFS-S23/CFFS-22-23/data/cleaning/non_std_items_in_items_list_assigned/rows_not_in_conversions.csv', index = False, header = True)
