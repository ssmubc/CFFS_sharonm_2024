# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ok_check = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23.csv")
ok_check
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 208  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 209  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 210  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 211  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 212  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
ok_check.tail(30)
# Out:
#       ProdId                     Description                      SalesGroup  \
# 183  R-61807   SQR|STEW|Mushroom & Squash +1                OK - SQUARE MEAL
# 184  R-57343          SQR|Veg Bangers & Mash                OK - SQUARE MEAL
# 185  R-64742             SQR|Veg Lentil Loaf                OK - SQUARE MEAL
# 186  R-51314    SQU|Chayote Salad Tostadas+1                OK - SQUARE MEAL
# 187  R-57098     VEG|Kale Wh Bean Quesadilla         OK - VEGETARIAN KITCHEN
# 188  R-60526  VEG|Kale White Bean Quesadilla         OK - VEGETARIAN KITCHEN
# 189  R-52812  VEG|Roast Vegetable Quesadilla         OK - VEGETARIAN KITCHEN
# 190  R-46913      VEG|Roasted Veg Quesadilla         OK - VEGETARIAN KITCHEN
# 191  R-55133   VEG|Spin Artichoke Quesadilla         OK - VEGETARIAN KITCHEN
# 192  R-60319    VEG|Spin Mush Avo Quesadilla  OK- VEGETARIAN KITCHEN FEATURE
# 193  R-57096    VEG|Spin Mushroom Quesadilla         OK - VEGETARIAN KITCHEN
# ...

# %%
41+74+98
# Out:
# 213

# %%
87+4+94
# Out:
# 185

# %%
items = pd.read_csv("data/preprocessed/Items_List.csv")
items
# Out:
#       ItemId                     Description  CaseQty CaseUOM  PakQty PakUOM  \
# 0     I-4271             APPLES GRANNY SMITH    113.0      ea     1.0     CT
# 1     I-4971     ARTICHOKE 1/4 SALAD CUT TFC      6.0  LG CAN     2.5     Kg
# 2     I-2305                  BACON PANCETTA      1.0      Kg     1.0     Kg
# 3     I-1207                 BAGUETTE FRENCH     24.0    each     1.0     CT
# 4    I-17203                  BALSAMIC GLAZE      2.0  bottle     2.0      L
# ..       ...                             ...      ...     ...     ...    ...
# 737   I-1127  PIE SHELL U/SWT DEEP DISH 5IN     120.0      CT     1.0     CT
# 738  I-43646                 PORK SKEWER 75G      1.0      CT     1.0     CT
# 739  I-57557      PRAWN WHT PD T/OF 31/40 OW      1.0      lb     1.0     lb
# 740   I-8238        SPRING ROLL VEG 30g SIZE     90.0      ea     1.0     ea
# 741   I-9341               TORTILLA FLOUR 6"     24.0     pak    12.0     CT
#
#              InventoryGroup
# ...

# %%
ingredient = pd.read_csv("data2/preprocessed/Ingredients_List.csv")
ingredient
# Out:
#      IngredientId     Qty    Uom  Conversion  InvFactor   Recipe
# 0         P-18746    1.00     Kg    1.000000     1.0000  P-10241
# 1          I-3388    1.00      L    1.000000     0.3058  P-10496
# 2          I-4660    2.27     Kg    2.204620     0.6942  P-10496
# 3          I-3451    2.56      L    1.000000     1.2800  P-13933
# 4          I-4679    1.00  BUNCH    1.000000     0.0063  P-18318
# ...           ...     ...    ...         ...        ...      ...
# 5377      P-26143  170.00      g    0.001000     1.0000  R-62022
# 5378      P-26225  140.00      g    0.002205     1.0000  R-62022
# 5379      P-50428    3.00      g    1.000000     1.0000  R-62022
# 5380      P-56712  180.00      g    0.001000     1.0000  R-62022
# 5381      P-56927   90.00      g    0.001000     1.0000  R-62022
#
# [5382 rows x 6 columns]

# %%
items_assigned = pd.read_csv("data/mapping/Items_List_Assigned.csv")
items_assigned
# Out:
#          ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0       I-57545         1.0         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1       I-10869         1.0             BEEF STIRFRY COV FR     5.00      Kg
# 2        I-7064         1.0           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3       I-37005         1.0                  BEEF MEATBALLS     4.54      Kg
# 4       I-37002         1.0        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...         ...         ...                             ...      ...     ...
# 2010     I-9344         6.0                 CHEESE BRIE GFS     2.65      lb
# 2011    I-41924        18.0  PEA GREEN ASSORTED GRADE A IQF     6.00      ea
# 2012    I-63875        58.0         SAUCE SOY TAMARI G/FREE    11.34       L
# 2013    I-39593        35.0                       JACKFRUIT    24.00     can
# 2014  I-3959335        35.0                       JACKFRUIT    24.00     can
#
#         PakQty PakUOM  InventoryGroup
# ...

# %%
ch = pd.read_csv("practice/notebook2_checkpoint.csv")
ch.tail(32)
# Out:
#        ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 1976  I-22915         3.0                   PORK FEET CUT      1.0      Kg
# 1977  I-64876        18.0       TMRW BURGER PATTIES VEGAN     40.0    each
# 1978  I-64877         3.0    TMRW SAUSAGE BREAKFAST PATTY    100.0    each
# 1979  I-55331         4.0  CHICK BREAST BL/SO HAL TENDOUT      1.0      Kg
# 1980   I-3999         4.0           CHICK DRUMSTICK HALAL      1.0      Kg
# 1981   I-4465        36.0            ASPARAGUS (LARGE) MX     11.0      lb
# 1982  I-22443        40.0             BAMBOO SHOOTS STRIP      6.0  LG CAN
# 1983  I-10616        17.0                   BEANS ROMANO       1.0      lb
# 1984   I-4582        38.0         CARROTS BABY BUNCHED BC      1.0    each
# 1985  I-11670        40.0     COLESLAW MIX CABBAGE&CARROT      5.0      lb
# 1986  I-10265        37.0            TOMATOES HEIRLOOM BC      1.0      lb
# ...

# %%
ch.drop_duplicates(subset=["ItemId"], inplace=True)
ch
# Out:
#        ItemId  CategoryID                Description  CaseQty CaseUOM  PakQty  \
# 0     I-57545         1.0    CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1     I-10869         1.0        BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2      I-7064         1.0      BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3     I-37005         1.0             BEEF MEATBALLS     4.54      Kg  1000.0
# 4     I-37002         1.0   BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
# ...       ...         ...                        ...      ...     ...     ...
# 2003  I-19464        25.0    NOODLES RICE VERMICELLI    30.00     pak   400.0
# 2004   I-3701        19.0         NUT 1KG PISTACHIO      1.00      Kg     1.0
# 2005  I-29755        18.0     PEAS GREEN WASABI BULK  5000.00       g     1.0
# 2006   I-4524        38.0               BEETS GOLDBC     5.00      lb     1.0
# 2007   I-1271        24.0  LOAF MARBLE RYE SANDWICH      4.00    LOAF     1.0
#
#      PakUOM  InventoryGroup  \
# ...

# %%
ch.loc[ch["ItemId"] == "I-1271"]
# Out:
#       ItemId  CategoryID                Description  CaseQty CaseUOM  PakQty  \
# 2007  I-1271        24.0  LOAF MARBLE RYE SANDWICH       4.0    LOAF     1.0
#
#      PakUOM InventoryGroup  \
# 2007   LOAF          BREAD
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)
# 2007                                             1.5225

# %%
ch["ItemId"].isnull().any()
# Out:
# False

# %%
duplicate = ch[ch.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [ItemId, CategoryID, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup, Active Total Supply Chain Emissions (kg CO2 / kg food)]
# Index: []

# %%
ch1 = ch.drop_duplicates(subset=["ItemId"], inplace=False)
ch1
# Out:
#        ItemId  CategoryID                Description  CaseQty CaseUOM  PakQty  \
# 0     I-57545         1.0    CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1     I-10869         1.0        BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2      I-7064         1.0      BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3     I-37005         1.0             BEEF MEATBALLS     4.54      Kg  1000.0
# 4     I-37002         1.0   BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
# ...       ...         ...                        ...      ...     ...     ...
# 2003  I-19464        25.0    NOODLES RICE VERMICELLI    30.00     pak   400.0
# 2004   I-3701        19.0         NUT 1KG PISTACHIO      1.00      Kg     1.0
# 2005  I-29755        18.0     PEAS GREEN WASABI BULK  5000.00       g     1.0
# 2006   I-4524        38.0               BEETS GOLDBC     5.00      lb     1.0
# 2007   I-1271        24.0  LOAF MARBLE RYE SANDWICH      4.00    LOAF     1.0
#
#      PakUOM  InventoryGroup  \
# ...

# %%
ch1.loc[ch1["ItemId"] == "I-19464"]
# Out:
#        ItemId  CategoryID              Description  CaseQty CaseUOM  PakQty  \
# 2003  I-19464        25.0  NOODLES RICE VERMICELLI     30.0     pak   400.0
#
#      PakUOM  InventoryGroup  \
# 2003      g  FOOD - GROCERY
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)
# 2003                                             2.5345

# %%
ingredient.loc[ingredient["IngredientId"] == "R-37429"]
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
item = pd.read_csv("data/preprocessed/Items_List.csv")
item.loc[item["ItemId"] == "I-68718"]
# Out:
# Empty DataFrame
# Columns: [ItemId, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
upc = pd.read_csv("data/cleaning/update/Conv_UpdateConv.csv")
upc
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0         I-1028    0.008333             1.0             CT         120.0
# 1         I-1034    0.008333             1.0             CT         120.0
# 2         I-1035    0.010000             1.0             CT         100.0
# 3        I-10605    0.008850             1.0             CT         113.0
# 4         I-1126    0.006667             1.0             CT         150.0
# ..           ...         ...             ...            ...           ...
# 335       I-9641    0.017544             1.0           LOAF          57.0
# 336      I-14190    0.001667             1.0           LOAF         600.0
# 337      I-37113    0.004274             1.0             ea         234.0
# 338       I-1271    0.000111             0.1           LOAF         900.0
# 339      I-68718    0.011765             1.0           each          85.0
#
#     ConvertToUom
# 0              g
# 1              g
# 2              g
# ...

# %%
def assign_multiplier(df):
    for ind, row in df.iterrows():
        if pd.isnull(row["Multiplier"]):
            df.loc[ind, "Multiplier"] = row["ConvertFromQty"] / row["ConvertToQty"]
        
assign_multiplier(upc)
upc
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0         I-1028    0.008333             1.0             CT         120.0
# 1         I-1034    0.008333             1.0             CT         120.0
# 2         I-1035    0.010000             1.0             CT         100.0
# 3        I-10605    0.008850             1.0             CT         113.0
# 4         I-1126    0.006667             1.0             CT         150.0
# ..           ...         ...             ...            ...           ...
# 335       I-9641    0.017544             1.0           LOAF          57.0
# 336      I-14190    0.001667             1.0           LOAF         600.0
# 337      I-37113    0.004274             1.0             ea         234.0
# 338       I-1271    0.000111             0.1           LOAF         900.0
# 339      I-68718    0.011765             1.0           each          85.0
#
#     ConvertToUom
# 0              g
# 1              g
# 2              g
# ...

# %%
origin = pd.read_csv("practice/step4_checkpoint1.csv")
origin
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 758      P-55709         NaN             1.0            PTN        185.00
# 759      P-62293         NaN             1.0            PTN        185.00
# 760      P-62023         NaN             1.0           ROLL        155.00
# 761      P-54581         NaN            22.0          slice         38.00
# 762          NaN         NaN             NaN            NaN           NaN
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
revision = pd.read_csv("practice/step4_checkpoint2.csv")
revision
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 706      P-55707    0.005405             1.0            PTN        185.00
# 707      P-55709    0.005405             1.0            PTN        185.00
# 708      P-62293    0.005405             1.0            PTN        185.00
# 709      P-62023    0.006452             1.0           ROLL        155.00
# 710      P-54581    0.578947            22.0          slice         38.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
ch3 = pd.read_csv("practice/step4_checkpoint3.csv")
ch3
# Out:
#       PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0    P-50310      BATTER|Pancake|Carrot Cake     5.0      L           PREP
# 1    P-50317  BATTER|Pancake|Lemon Poppyseed     5.0      L           PREP
# 2    P-28285                 BATTER|Pancakes     4.8     Kg           PREP
# 3    P-50739          COMPOTE|Apple Cinnamon     2.5      L           PREP
# 4    P-26063               COMPOTE|Blueberry     2.6      L           PREP
# ..       ...                             ...     ...    ...            ...
# 420  P-54657                   YIELD|Avocado   120.0      g            NaN
# 421  P-45255            YIELD|Chicken Strips    70.0  piece            NaN
# 422  P-57092           YIELD|Chopped Romaine   620.0      g           PREP
# 423  P-50809        YIELD|Country Loaf|Slice    18.0  slice            NaN
# 424  P-50695        YIELD|Lettuce Green Leaf     8.5     lb            NaN
#
# ...

# %%
ch4 = pd.read_csv("practice/step4_checkpoint4.csv")
ch4
# Out:
#       PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0    P-50310      BATTER|Pancake|Carrot Cake     5.0      L           PREP
# 1    P-50317  BATTER|Pancake|Lemon Poppyseed     5.0      L           PREP
# 2    P-28285                 BATTER|Pancakes     4.8     Kg           PREP
# 3    P-50739          COMPOTE|Apple Cinnamon     2.5      L           PREP
# 4    P-26063               COMPOTE|Blueberry     2.6      L           PREP
# ..       ...                             ...     ...    ...            ...
# 420  P-54657                   YIELD|Avocado   120.0      g            NaN
# 421  P-45255            YIELD|Chicken Strips    70.0  piece            NaN
# 422  P-57092           YIELD|Chopped Romaine   620.0      g           PREP
# 423  P-50809        YIELD|Country Loaf|Slice    18.0  slice            NaN
# 424  P-50695        YIELD|Lettuce Green Leaf     8.5     lb            NaN
#
# ...

# %%
ch5 = pd.read_csv("practice/step4_checkpoint5.csv")
ch5
# Out:
#       PrepId                     Description  PakQty PakUOM InventoryGroup  \
# 0    P-50310      BATTER|Pancake|Carrot Cake     5.0      L           PREP
# 1    P-50317  BATTER|Pancake|Lemon Poppyseed     5.0      L           PREP
# 2    P-28285                 BATTER|Pancakes     4.8     Kg           PREP
# 3    P-50739          COMPOTE|Apple Cinnamon     2.5      L           PREP
# 4    P-26063               COMPOTE|Blueberry     2.6      L           PREP
# ..       ...                             ...     ...    ...            ...
# 420  P-54657                   YIELD|Avocado   120.0      g            NaN
# 421  P-45255            YIELD|Chicken Strips    70.0  piece            NaN
# 422  P-57092           YIELD|Chopped Romaine   620.0      g           PREP
# 423  P-50809        YIELD|Country Loaf|Slice    18.0  slice            NaN
# 424  P-50695        YIELD|Lettuce Green Leaf     8.5     lb            NaN
#
# ...

# %%
ch6 = pd.read_csv("practice/step4_checkpoint6.csv")
ch6.tail(50)
# Out:
#       ProdId                    Description                    SalesGroup  \
# 75   R-68190       VEG|Mushroom B'Fast Bowl       OK - VEGETARIAN KITCHEN
# 76   R-56509       VEG|Quesadilla|Breakfast       OK - VEGETARIAN KITCHEN
# 77   R-56688                  VEG|Shakshuka       OK - VEGETARIAN KITCHEN
# 78   R-27272      VEG|Tuscan Breakfast Bowl              OK - SQUARE MEAL
# 79   R-44308           BNO|Bowl Pulled Pork         OK - BURRITO KITCHEN
# 80   R-67993                     BOWL|Japan             OK - FLEX KITCHEN
# 81   R-67987             BOWL|Mediterranean             OK - FLEX KITCHEN
# 82   R-67988                    BOWL|Mexico             OK - FLEX KITCHEN
# 83   R-67989                      BOWL|Thai             OK - FLEX KITCHEN
# 84   R-68195                   BOWL|Vietnam             OK - FLEX KITCHEN
# 85   R-68206          BOWL|Westcoast Winter                    OK - SIDES
# 86   R-37170                      CST|Beef            OK - CUSTOM KITCHEN
# ...

# %%
mapping = pd.read_csv("data/mapping/Mapping.csv")
mapping
# Out:
#          ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0       I-57545           1         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1       I-10869           1             BEEF STIRFRY COV FR     5.00      Kg
# 2        I-7064           1           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3       I-37005           1                  BEEF MEATBALLS     4.54      Kg
# 4       I-37002           1        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...         ...         ...                             ...      ...     ...
# 2010     I-9344           6                 CHEESE BRIE GFS     2.65      lb
# 2011    I-41924          18  PEA GREEN ASSORTED GRADE A IQF     6.00      ea
# 2012    I-63875          58         SAUCE SOY TAMARI G/FREE    11.34       L
# 2013    I-39593          35                       JACKFRUIT    24.00     can
# 2014  I-3959335          35                       JACKFRUIT    24.00     can
#
#         PakQty PakUOM  InventoryGroup  \
# ...

# %%
mapping["Freshwater Withdrawals (L/FU)"].unique()
# Out:
# array([1.67720000e+03, 4.61200000e+02, 1.81030000e+03, 3.70300000e+02,
#        1.01017600e+03, 1.55930000e+03, 1.62000000e+01, 2.80800000e+01,
#        1.97300000e+02, 2.62409000e+02, 6.32900000e+02, 1.58050000e+03,
#        1.20780000e+03, 0.00000000e+00, 9.00200000e+02, 6.60000000e+00,
#        6.77075000e+02, 4.39000000e+01, 6.70300000e+02, 4.19200000e+02,
#        1.57490000e+03, 1.82330000e+03, 4.55825000e+02, 6.70300000e+01,
#        1.30000000e+00, 3.50000000e+00, 1.14500000e+02, 1.00000000e+00,
#        4.03500000e+02, 3.74000000e+01, 5.45000000e+01, 7.70000000e+01,
#        9.90000000e+00, 1.90000000e+00, 8.13000000e+01, 2.60000000e+00,
#        1.01000000e+01, 6.75000000e+01, 1.40000000e+00, 3.17900000e+02,
#        7.00000000e+00, 4.50000000e+00, 2.49000000e+01, 3.33000000e+01,
#        2.02250000e+01, 1.34680000e+03, 1.03884000e+03, 9.49890000e+01,
#        8.65280000e+01, 6.19750000e+02, 2.50250000e+02, 6.00075000e+02,
# ...

# %%
conversions = pd.read_csv("data/cleaning/Conversions_Added.csv")
conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 630       I-9641    0.017544             1.0           LOAF         57.00
# 631      I-14190    0.001667             1.0           LOAF        600.00
# 632      I-37113    0.004274             1.0             ea        234.00
# 633       I-1271    0.000111             0.1           LOAF        900.00
# 634      I-68718    0.011765             1.0           each         85.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
ingredients = pd.read_csv("data/preprocessed/Ingredients_List.csv")
ingredients
# Out:
#      IngredientId     Qty    Uom  Conversion  InvFactor   Recipe
# 0         P-18746    1.00     Kg    1.000000     1.0000  P-10241
# 1          I-3388    1.00      L    1.000000     0.3058  P-10496
# 2          I-4660    2.27     Kg    2.204620     0.6942  P-10496
# 3          I-3451    2.56      L    1.000000     1.2800  P-13933
# 4          I-4679    1.00  BUNCH    1.000000     0.0063  P-18318
# ...           ...     ...    ...         ...        ...      ...
# 6705      P-54344    1.00    tsp    0.004733     1.0000  R-62630
# 6706      P-62629    2.00   each    1.000000     1.0000  R-62630
# 6707      P-62632   50.00      g    0.001000     1.0000  R-62633
# 6708      P-54344    1.00    tsp    0.004733     1.0000  R-62638
# 6709      P-62637  120.00      g    0.002205     1.0000  R-62638
#
# [6710 rows x 6 columns]

# %%
conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 630       I-9641    0.017544             1.0           LOAF         57.00
# 631      I-14190    0.001667             1.0           LOAF        600.00
# 632      I-37113    0.004274             1.0             ea        234.00
# 633       I-1271    0.000111             0.1           LOAF        900.00
# 634      I-68718    0.011765             1.0           each         85.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
c_check = pd.read_csv("practice/conversion_check.csv")
c_check
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 706      P-55707    0.005405             1.0            PTN        185.00
# 707      P-55709    0.005405             1.0            PTN        185.00
# 708      P-62293    0.005405             1.0            PTN        185.00
# 709      P-62023    0.006452             1.0           ROLL        155.00
# 710      P-54581    0.578947            22.0          slice         38.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
def assign_multiplier(update_conv):
    for ind, row in update_conv.iterrows():
        if pd.isnull(row["Multiplier"]):
            update_conv.loc[ind, "Multiplier"] = row["ConvertFromQty"] / row["ConvertToQty"]
    return update_conv

# %%
conversion1 = assign_multiplier(c_check)
conversion1
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 706      P-55707    0.005405             1.0            PTN        185.00
# 707      P-55709    0.005405             1.0            PTN        185.00
# 708      P-62293    0.005405             1.0            PTN        185.00
# 709      P-62023    0.006452             1.0           ROLL        155.00
# 710      P-54581    0.578947            22.0          slice         38.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
c_check["Multiplier"].isnull().sum()
# Out:
# 0

# %%
ch7 = pd.read_csv("practice/step4_checkpoint7.csv")
ch7
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 120  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 121  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 122  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 123  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 124  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
final = pd.read_csv("data/final/Recipes Footprints.csv")
final
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
print(final.shape)
# Out:
# (610, 12)

# %%
count = pd.read_csv("practice/step5_checkpoint.csv")
count = count.rename(columns={"Unnamed: 0":"Color"})
sns.set_theme(style="darkgrid")
fig, axes = plt.subplots(1,2, figsize=(9,5), sharex=False, sharey=True)
fig.set_title="Color Comparison"
ax1 = sns.barplot(x=count["Color"], y=count["GHG Label Counts"], ax=axes[0])
ax1.set_title = "GHG Emission Label Counts"
ax1.set_ylabel= ""
ax2 =sns.barplot(x=count["Color"], y=count["Final Label Counts"], ax=axes[1])
ax2.set_title = "All Emissions Label Counts"
ax2.set_ylabel= ""
for ax in [ax1, ax2]:
    for i in ax.containers:
        ax.bar_label(i,)
plt.show()

# %%
extra = pd.read_csv("practice/extra_items_checkpoint.csv")
extra
# Out:
#          ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0       I-57545         1.0         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1       I-10869         1.0             BEEF STIRFRY COV FR     5.00      Kg
# 2        I-7064         1.0           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3       I-37005         1.0                  BEEF MEATBALLS     4.54      Kg
# 4       I-37002         1.0        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...         ...         ...                             ...      ...     ...
# 2010     I-9344         6.0                 CHEESE BRIE GFS     2.65      lb
# 2011    I-41924        18.0  PEA GREEN ASSORTED GRADE A IQF     6.00      ea
# 2012    I-63875        58.0         SAUCE SOY TAMARI G/FREE    11.34       L
# 2013    I-39593        35.0                       JACKFRUIT    24.00     can
# 2014  I-3959335        35.0                       JACKFRUIT    24.00     can
#
#         PakQty PakUOM  InventoryGroup  \
# ...

# %%
mapping = pd.read_csv("practice/mapping_checkpoint.csv")
mapping
# Out:
#          ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0       I-57545           1         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1       I-10869           1             BEEF STIRFRY COV FR     5.00      Kg
# 2        I-7064           1           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3       I-37005           1                  BEEF MEATBALLS     4.54      Kg
# 4       I-37002           1        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...         ...         ...                             ...      ...     ...
# 2010     I-9344           6                 CHEESE BRIE GFS     2.65      lb
# 2011    I-41924          18  PEA GREEN ASSORTED GRADE A IQF     6.00      ea
# 2012    I-63875          58         SAUCE SOY TAMARI G/FREE    11.34       L
# 2013    I-39593          35                       JACKFRUIT    24.00     can
# 2014  I-3959335          35                       JACKFRUIT    24.00     can
#
#         PakQty PakUOM  InventoryGroup  \
# ...

# %%
mapping.loc[mapping["ItemId"] == "I-3959335"]
# Out:
#          ItemId  CategoryID Description  CaseQty CaseUOM  PakQty PakUOM  \
# 2014  I-3959335          35   JACKFRUIT     24.0     can   550.0     ml
#
#       InventoryGroup  Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 2014  FOOD - GROCERY                                             0.3942
#
#       g N lost/kg product  Freshwater Withdrawals (L/FU)  \
# 2014                  2.7                           37.4
#
#       Stress-Weighted Water Use (L/FU)
# 2014                            1345.5

# %%
name = pd.read_csv("practice/item_name.csv")
name.head(50)
# Out:
#                Displayed Name   ProdId                     Description  \
# 0                    4 Cheese  R-61778          ALF|Flatbread|4 Cheese
# 1                         NaN  R-61780  ALF|Flatbread|Apple & Pancetta
# 2                 BBQ Chicken  R-61749       ALF|Flatbread|BBQ Chicken
# 3                  Bruschetta  R-50859        ALF|Flatbread|Bruschetta
# 4                     Caprese  R-50788           ALF|Flatbread|Caprese
# 5                         NaN  R-61781   ALF|Flatbread|Chick Artichoke
# 6                       Greek  R-50858             ALF|Flatbread|Greek
# 7               Hawaii-Five-O  R-61498     ALF|Flatbread|Hawaii Five-0
# 8                     Italian  R-50562           ALF|Flatbread|Italian
# 9   Mediterranean (Flatbread)  R-56337     ALF|Flatbread|Mediterranean
# 10                        NaN  R-61782          ALF|Flatbread|Mushroom
# 11             Mushroom Pesto  R-61779    ALF|Flatbread|Mushroom Pesto
# ...

# %%
name.loc[name["ProdId"] == "R-37170"]
# Out:
#     Displayed Name   ProdId Description           SalesGroup  Weight (g)  \
# 406           Beef  R-37170    CST|Beef  OK - CUSTOM KITCHEN       629.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 406       4769.391295   32.273613                      239.87
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 406                        7045.39                   758.25
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 406               5.13                              38.14
#
#      Stress-Weighted Water Use (L) / 100g GHG Only Label Combined Label
# 406                               1120.09            Red            Red

# %%
mapped = pd.read_csv("data/mapping/Mapping.csv")
mapped
# Out:
#          ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0       I-57545           1         CHUCK FLAT BONELESS FZN     3.30      Kg
# 1       I-10869           1             BEEF STIRFRY COV FR     5.00      Kg
# 2        I-7064           1           BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3       I-37005           1                  BEEF MEATBALLS     4.54      Kg
# 4       I-37002           1        BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...         ...         ...                             ...      ...     ...
# 2010     I-9344           6                 CHEESE BRIE GFS     2.65      lb
# 2011    I-41924          18  PEA GREEN ASSORTED GRADE A IQF     6.00      ea
# 2012    I-63875          58         SAUCE SOY TAMARI G/FREE    11.34       L
# 2013    I-39593          35                       JACKFRUIT    24.00     can
# 2014  I-3959335          35                       JACKFRUIT    24.00     can
#
#         PakQty PakUOM  InventoryGroup  \
# ...

# %%
mapped.loc[mapped["ItemId"] == "I-19923"]
# Out:
#        ItemId  CategoryID           Description  CaseQty CaseUOM  PakQty  \
# 1989  I-19923          12  HALIBUT STEAK 4OZ.OW      1.0      lb     1.0
#
#      PakUOM InventoryGroup  \
# 1989     lb        SEAFOOD
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 1989                                             4.9798
#
#       g N lost/kg product  Freshwater Withdrawals (L/FU)  \
# 1989                 70.3                         1580.5
#
#       Stress-Weighted Water Use (L/FU)
# 1989                            8483.4

# %%
error_check = pd.read_csv("practice/error_check.csv")
error_check
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 794      P-62293    0.005405             1.0            PTN        185.00
# 795      P-62023    0.006452             1.0           ROLL        155.00
# 796      P-54581    0.578947            22.0          slice         38.00
# 797      P-50511    0.015385             1.0           each         65.00
# 798      P-32729    0.011765             4.0           each        340.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
conversions = pd.read_csv("data/cleaning/Conversions_Added.csv")
conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 630       I-9641    0.017544             1.0           LOAF         57.00
# 631      I-14190    0.001667             1.0           LOAF        600.00
# 632      I-37113    0.004274             1.0             ea        234.00
# 633       I-1271    0.000111             0.1           LOAF        900.00
# 634      I-68718    0.011765             1.0           each         85.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
conversions.loc[conversions["ConversionId"] == "P-32729"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
conv = pd.read_csv("practice/conversion_checkpoint.csv", na_values=['NAN'])
conv
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 794      P-62293    0.005405             1.0            PTN        185.00
# 795      P-62023    0.006452             1.0           ROLL        155.00
# 796      P-54581    0.578947            22.0          slice         38.00
# 797      P-50511    0.015385             1.0           each         65.00
# 798      P-32729    0.011765             4.0           each        340.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
conv2 = pd.read_csv("practice/conv_checkpoint2.csv")
conv2.tail(30)
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 759      P-48485         NaN             1.0          slice          70.0
# 760      P-50510         NaN             1.0          slice          70.0
# 761      P-22030         NaN             1.0          slice         100.0
# 762      P-63831         NaN             1.0          slice         100.0
# 763      P-38172         NaN             1.0            PTN         100.0
# 764      P-22048         NaN             1.0          slice         100.0
# 765      P-22042         NaN             1.0          slice         100.0
# 766      P-22049         NaN             1.0          slice         100.0
# 767      P-63830         NaN             1.0          slice         100.0
# 768      P-38170         NaN             1.0            PTN         100.0
# 769      P-13850         NaN            30.0          slice        5105.0
# 770      P-53808         NaN            36.0             CT        2141.0
# ...

# %%
conv3 = pd.read_csv("practice/conv_checkpoint3.csv")
conv3
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 794      P-62293    0.005405             1.0            PTN        185.00
# 795      P-62023    0.006452             1.0           ROLL        155.00
# 796      P-54581    0.578947            22.0          slice         38.00
# 797      P-50511    0.015385             1.0           each         65.00
# 798      P-32729    0.011765             4.0           each        340.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
std_unit = pd.read_csv("data/external/standard_conversions.csv")
std_unit
# Out:
#       Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty ConvertToUom
# 0       4.928900               1            tsp      4.928900           ml
# 1      14.787000               1           Tbsp     14.787000           ml
# 2     946.350000               1             qt    946.350000           ml
# 3     473.176250               1             pt    473.176250           ml
# 4      28.349500               1             oz     28.349500            g
# 5       0.001000            1000             mg      1.000000            g
# 6     453.592000               1             lb    453.592000            g
# 7    1000.000000               1              L   1000.000000           ml
# 8    1000.000000               1             Kg   1000.000000            g
# 9   58600.000000               1         keg59L  58600.000000           ml
# 10  50000.000000               1         keg50L  50000.000000           ml
# ...

# %%
conv3.loc[conv3["ConversionId"] == "P-54581"]
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 796      P-54581    0.578947            22.0          slice          38.0
#
#     ConvertToUom
# 796            g

# %%
df = pd.merge(conv2, conv3, how='outer', suffixes=('','_y'), indicator=True)
rows_in_df1_not_in_df2 = df[df['_merge']=='left_only'][conv2.columns]
rows_in_df1_not_in_df2.head()
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 103       I-3582    0.166667             1.0            tsp           6.0
# 104       I-3582    0.055556             1.0           Tbsp          18.0
# 105       I-3582    0.003425             1.0            cup         292.0
# 123       I-3651    1.428571             1.0            tsp           0.7
# 124       I-3651    0.476190             1.0           Tbsp           2.1
#
#     ConvertToUom
# 103            g
# 104            g
# 105            g
# 123            g
# 124            g

# %%
link_prep = pd.read_csv("practice/link_prep_checkpoint.csv")
link_prep
# Out:
#       PrepId                  Description  PakQty PakUOM InventoryGroup  \
# 0    P-55516  BAKED|Lasagna|Spin Mushroom   5.550     Kg            NaN
# 1    P-54666  BAKED|Pasta|Chicken Alfredo   6.176     Kg            NaN
# 2    P-54664    BAKED|Pasta|Chorizo Penne   7.360     Kg            NaN
# 3    P-56502     BAKED|Pasta|Shrimp Pesto   5.760     Kg            NaN
# 4    P-56433       BATCH|Shrimp Remoulade   1.600     Kg            NaN
# ..       ...                          ...     ...    ...            ...
# 874  P-62520         SQR|Cauliflower Taco   1.000    PTN            NaN
# 875  P-62597      SQR|Chipotle Prawn Taco   1.000    PTN            NaN
# 876  P-60813            TART|Spinach Feta   1.000     ea            NaN
# 877  P-62442               WEDGE|Lime|1/6   1.000     CT            NaN
# 878  P-53751            YIELD|Fennel Bulb   2.300     Kg            NaN
#
#           StdQty StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  \
# ...

# %%
link_prep.loc[link_prep["PrepId"] == "P-26216"]
# Out:
#      PrepId            Description  PakQty PakUOM InventoryGroup  StdQty  \
# 16  P-26216  COOKED|Pasta|Penne|WW     2.9     Kg           PREP  2900.0
#
#    StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  N lost (g)  \
# 16      g           2612.16                 0.900745       22.22
#
#     N lost (g)/StdUom  Freshwater Withdrawals (ml)  \
# 16           0.007662                     648940.0
#
#     Freshwater Withdrawals (ml)/StdUom  Stress-Weighted Water Use (ml)  \
# 16                          223.772414                      19253910.0
#
#     Stress-Weighted Water Use (ml)/StdUom
# 16                             6639.27931

# %%
link_prep.loc[link_prep["PrepId"] == "P-54664"]
# Out:
#     PrepId                Description  PakQty PakUOM InventoryGroup  StdQty  \
# 2  P-54664  BAKED|Pasta|Chorizo Penne    7.36     Kg            NaN  7360.0
#
#   StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  N lost (g)  \
# 2      g         18065.912                 2.454608     220.216
#
#    N lost (g)/StdUom  Freshwater Withdrawals (ml)  \
# 2           0.029921                    3254896.0
#
#    Freshwater Withdrawals (ml)/StdUom  Stress-Weighted Water Use (ml)  \
# 2                          442.241304                     127219936.0
#
#    Stress-Weighted Water Use (ml)/StdUom
# 2                           17285.317391

# %%
preps = pd.read_csv("data/preprocessed/Preps_List.csv")
preps
# Out:
#       PrepId                  Description  PakQty PakUOM InventoryGroup
# 0    P-55516  BAKED|Lasagna|Spin Mushroom   5.550     Kg            NaN
# 1    P-54666  BAKED|Pasta|Chicken Alfredo   6.176     Kg            NaN
# 2    P-54664    BAKED|Pasta|Chorizo Penne   7.360     Kg            NaN
# 3    P-56502     BAKED|Pasta|Shrimp Pesto   5.760     Kg            NaN
# 4    P-56433       BATCH|Shrimp Remoulade   1.600     Kg            NaN
# ..       ...                          ...     ...    ...            ...
# 923  P-62520         SQR|Cauliflower Taco   1.000    PTN            NaN
# 924  P-62597      SQR|Chipotle Prawn Taco   1.000    PTN            NaN
# 925  P-60813            TART|Spinach Feta   1.000     ea            NaN
# 926  P-62442               WEDGE|Lime|1/6   1.000     CT            NaN
# 927  P-53751            YIELD|Fennel Bulb   2.300     Kg            NaN
#
# [928 rows x 5 columns]

# %%
preps.loc[preps["PrepId"] == "P-26068"]
# Out:
#     PrepId               Description  PakQty PakUOM InventoryGroup
# 9  P-26068  COOKED|Caramelized Onion     1.2     Kg           PREP

# %%
prep_ghge = pd.read_csv("practice/get_items_checkpoint.csv")
prep_ghge
# Out:
#       PrepId                  Description  PakQty PakUOM InventoryGroup  \
# 0    P-55516  BAKED|Lasagna|Spin Mushroom   5.550     Kg            NaN
# 1    P-54666  BAKED|Pasta|Chicken Alfredo   6.176     Kg            NaN
# 2    P-54664    BAKED|Pasta|Chorizo Penne   7.360     Kg            NaN
# 3    P-56502     BAKED|Pasta|Shrimp Pesto   5.760     Kg            NaN
# 4    P-56433       BATCH|Shrimp Remoulade   1.600     Kg            NaN
# ..       ...                          ...     ...    ...            ...
# 874  P-62520         SQR|Cauliflower Taco   1.000    PTN            NaN
# 875  P-62597      SQR|Chipotle Prawn Taco   1.000    PTN            NaN
# 876  P-60813            TART|Spinach Feta   1.000     ea            NaN
# 877  P-62442               WEDGE|Lime|1/6   1.000     CT            NaN
# 878  P-53751            YIELD|Fennel Bulb   2.300     Kg            NaN
#
#           StdQty StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  \
# ...

# %%
prep_ghge.loc[prep_ghge["PrepId"] == "P-55438"]
# Out:
#      PrepId               Description  PakQty PakUOM InventoryGroup  StdQty  \
# 18  P-55438  COOKED|WW Elbow Macaroni    9.09     Kg           PREP  9090.0
#
#    StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  N lost (g)  \
# 18      g       7004.445215                 0.770566    67.19767
#
#     N lost (g)/StdUom  Freshwater Withdrawals (ml)  \
# 18           0.007392                 1.923208e+06
#
#     Freshwater Withdrawals (ml)/StdUom  Stress-Weighted Water Use (ml)  \
# 18                          211.574003                    5.823090e+07
#
#     Stress-Weighted Water Use (ml)/StdUom
# 18                            6406.039995

# %%
prep_ghge.loc[prep_ghge["PrepId"] == "P-41095"]
# Out:
#      PrepId        Description  PakQty PakUOM InventoryGroup   StdQty StdUom  \
# 19  P-41095  DICED|Celery|1/4"  13.608     Kg            NaN  13608.0      g
#
#     GHG Emission (g)  GHG Emission (g)/StdUom  N lost (g)  N lost (g)/StdUom  \
# 19           11566.7                 0.849993       181.7           0.013352
#
#     Freshwater Withdrawals (ml)  Freshwater Withdrawals (ml)/StdUom  \
# 19                    1869900.0                          137.411817
#
#     Stress-Weighted Water Use (ml)  Stress-Weighted Water Use (ml)/StdUom
# 19                      67608500.0                            4968.290711

# %%
prep_ghge = pd.read_csv("practice/get_items_checkpoint.csv")
prep_ghge
# Out:
#       PrepId                  Description  PakQty PakUOM InventoryGroup  \
# 0    P-55516  BAKED|Lasagna|Spin Mushroom   5.550     Kg            NaN
# 1    P-54666  BAKED|Pasta|Chicken Alfredo   6.176     Kg            NaN
# 2    P-54664    BAKED|Pasta|Chorizo Penne   7.360     Kg            NaN
# 3    P-56502     BAKED|Pasta|Shrimp Pesto   5.760     Kg            NaN
# 4    P-56433       BATCH|Shrimp Remoulade   1.600     Kg            NaN
# ..       ...                          ...     ...    ...            ...
# 874  P-62520         SQR|Cauliflower Taco   1.000    PTN            NaN
# 875  P-62597      SQR|Chipotle Prawn Taco   1.000    PTN            NaN
# 876  P-60813            TART|Spinach Feta   1.000     ea            NaN
# 877  P-62442               WEDGE|Lime|1/6   1.000     CT            NaN
# 878  P-53751            YIELD|Fennel Bulb   2.300     Kg            NaN
#
#           StdQty StdUom  GHG Emission (g)  GHG Emission (g)/StdUom  \
# ...

# %%
conversions.loc[conversions["ConversionId"] == "P-62442"]
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 544      P-62442    0.071429             1.0             CT          14.0
#
#     ConvertToUom
# 544            g

# %%
def spc_converter(ingre, qty, uom, conversions, liquid_unit, solid_unit):
    """
    If the unit can be converted to standard units (g or ml), directs to std_converter.
    If ingre(IngredientId) is in spc_cov, find conversionId, converting unit, conversion unit from
    `data/cleaning/Conversions_Added.csv`.
    """

    spc_cov = list(filter(None, conversions["ConversionId"].tolist()))
    # spc_cov = [item for item in spc_cov if not (pd.null(item)) == True]

    if uom in liquid_unit + solid_unit:
        return std_converter(qty, uom)
    elif ingre in spc_cov:
        conversion = conversions.loc[(conversions["ConversionId"] == ingre) &
                                     (conversions["ConvertFromUom"] == uom) &
                                     (conversions["ConvertToUom"] == "g")]
        # conversion.drop_duplicates(subset=['ConversionId'], inplace=True)
        multiplier = conversion["Multiplier"]
        if multiplier.empty:
            return std_converter(qty, uom)
        else:
            Qty = float(qty) / float(multiplier)
            Uom = conversion["ConvertToUom"].values[0]
            return (Qty, Uom)
    else:
        return std_converter(qty, uom)

# %%
prep_ghge.loc[prep_ghge["PrepId"] == "P-54697"]
# Out:
#      PrepId      Description  PakQty PakUOM InventoryGroup  StdQty StdUom  \
# 36  P-54697  LEMON|Wedge 1/8     8.0   each           PREP    84.0      g
#
#     GHG Emission (g)  GHG Emission (g)/StdUom  N lost (g)  N lost (g)/StdUom  \
# 36         44.701492                 0.532161    0.306175           0.003645
#
#     Freshwater Withdrawals (ml)  Freshwater Withdrawals (ml)/StdUom  \
# 36                    4241.0852                            50.48911
#
#     Stress-Weighted Water Use (ml)  Stress-Weighted Water Use (ml)/StdUom
# 36                      152577.009                            1816.392964

# %%
ingre = pd.read_csv("data/preprocessed/Ingredients_List.csv")
ingre
# Out:
#      IngredientId     Qty    Uom  Conversion  InvFactor   Recipe
# 0         P-18746    1.00     Kg    1.000000     1.0000  P-10241
# 1          I-3388    1.00      L    1.000000     0.3058  P-10496
# 2          I-4660    2.27     Kg    2.204620     0.6942  P-10496
# 3          I-3451    2.56      L    1.000000     1.2800  P-13933
# 4          I-4679    1.00  BUNCH    1.000000     0.0063  P-18318
# ...           ...     ...    ...         ...        ...      ...
# 6705      P-54344    1.00    tsp    0.004733     1.0000  R-62630
# 6706      P-62629    2.00   each    1.000000     1.0000  R-62630
# 6707      P-62632   50.00      g    0.001000     1.0000  R-62633
# 6708      P-54344    1.00    tsp    0.004733     1.0000  R-62638
# 6709      P-62637  120.00      g    0.002205     1.0000  R-62638
#
# [6710 rows x 6 columns]

# %%
ingre.loc[ingre["Recipe"] == "P-56459"]
# Out:
#     IngredientId    Qty Uom  Conversion  InvFactor   Recipe
# 294       I-3370  250.0   g    0.950152      125.0  P-56459
# 295       I-3388  750.0  ml    0.001000      375.0  P-56459
# 296       I-3660  250.0   g    0.001000      125.0  P-56459
# 297       I-9382  750.0  ml    0.001000      375.0  P-56459
# 298      P-18907   20.0   g    1.000000       10.0  P-56459

# %%
mapped.loc[mapped["ItemId"] == "I-9382"]
# Out:
#       ItemId  CategoryID               Description  CaseQty CaseUOM  PakQty  \
# 1410  I-9382          57  VINEGAR APPLE CIDER PURE      2.0  bottle     5.0
#
#      PakUOM  InventoryGroup  \
# 1410      L  FOOD - GROCERY
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 1410                                               1.93
#
#       g N lost/kg product  Freshwater Withdrawals (L/FU)  \
# 1410                  0.0                            1.0
#
#       Stress-Weighted Water Use (L/FU)
# 1410                               1.0

# %%
conv2.loc[conv2["ConversionId"] == "P-26460"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
conversions1 = pd.read_csv("data/preprocessed/Conversions_List.csv")
conversions1
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 327       I-3113    0.067114             1.0           Tbsp         14.90
# 328       I-3113    0.004184             1.0            cup        239.00
# 329       I-4352    0.004274             1.0             CT        234.00
# 330      I-43646    0.011765             1.0             CT         85.00
# 331      I-43646    0.035294             3.0             oz         85.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
name[name['Displayed Name'].isnull()]
# Out:
#     Displayed Name   ProdId                     Description        SalesGroup  \
# 1              NaN  R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO
# 5              NaN  R-61781   ALF|Flatbread|Chick Artichoke     OK - AL FORNO
# 10             NaN  R-61782          ALF|Flatbread|Mushroom     OK - AL FORNO
# 13             NaN  R-50494        ALF|Flatbread|Proscuitto     OK - AL FORNO
# 15             NaN  R-61755  ALF|Flatbread|Roasted Root Veg     OK - AL FORNO
# ..             ...      ...                             ...               ...
# 605            NaN  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL
# 606            NaN  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL
# 607            NaN  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL
# 608            NaN  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL
# 609            NaN  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL
#
# ...

# %%
name[name["ProdId"] == "R-60528"]
# Out:
#       Displayed Name   ProdId   Description        SalesGroup  Weight (g)  \
# 551  Cous Cous/ Slaw  R-60528  SQ|COUS COUS  OK - SQUARE MEAL       170.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 551        144.507331    1.250081                       31.78
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 551                         980.83                     85.0
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 551               0.74                              18.69
#
#      Stress-Weighted Water Use (L) / 100g GHG Only Label Combined Label
# 551                                576.96          Green          Green

# %%
name["Displayed Name"].isnull().sum()
# Out:
# 463

# %%
products = pd.read_csv("data/preprocessed/Products_List.csv")
products
# Out:
#       ProdId                     Description        SalesGroup
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO
# ..       ...                             ...               ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL
#
# [610 rows x 3 columns]

# %%
products.loc[products["Description"] == "SKEWER|Teriyaki"]
# Out:
# Empty DataFrame
# Columns: [ProdId, Description, SalesGroup]
# Index: []

# %%
name["Displayed Name"].isnull().sum()
# Out:
# 463

# %%
OK = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23.csv")
OK
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 208  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 209  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 210  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 211  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 212  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
OK.loc[OK["ProdId"] == "R-56688"]
# Out:
#       ProdId    Description               SalesGroup  Weight (g)  \
# 118  R-56688  VEG|Shakshuka  OK - VEGETARIAN KITCHEN  349.000005
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 118        548.425457    6.499485                       87.99
#
#      Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 118                        3392.34                   157.14
#
#      N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 118               1.86                              25.21
#
#      Stress-Weighted Water Use (L) / 100g GHG Only Label Combined Label
# 118                                972.02          Green         Yellow

# %%
OK22 = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK22-23.csv")
OK22
# Out:
#       ProdId                   Description                    SalesGroup  \
# 0    R-30406  G&G|Croissant|Multigrain|OK                 OK - GRAB & GO
# 1    R-55155             GRL|Breakfast BLT  OK - GRILL KITCHEN BREAKFAST
# 2    R-44024            GRL|Breakfast Wrap  OK - GRILL KITCHEN BREAKFAST
# 3    R-50368        GRL|BreakfastCroissant  OK - GRILL KITCHEN BREAKFAST
# 4    R-50498      GRL|Crepe|Apple Cinnamon  OK - GRILL KITCHEN BREAKFAST
# ..       ...                           ...                           ...
# 218  R-68143  SANDWICH|Chicken Caesar Wrap  OK - SANDWICH KITCHEN EVENTS
# 219  R-61321          SANDWICH|Grilled Veg  OK - SANDWICH KITCHEN EVENTS
# 220  R-68075         SANDWICH|Tofu Bahn Mi         OK - SANDWICH KITCHEN
# 221  R-37630                SIDE|Soup|Miso                    OK - SOUP
# 222  R-27383               VEG|Incredibowl       OK - VEGETARIAN KITCHEN
#
#       Weight (g)  GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
OK21 = pd.read_csv("data/final/2022_2023_CFFS_Outcomes/Data_Labelled_OK21-22-pilot.csv")
OK21
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
OK21.loc[OK21["ProdId"] == "R-61778"]
# Out:
#     ProdId             Description     SalesGroup  Weight (g)  \
# 0  R-61778  ALF|Flatbread|4 Cheese  OK - AL FORNO       185.0
#
#    GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# 0         1229.9475      11.939                      212.84
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                       10662.59                   664.84               6.45
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                             115.05                               5763.56
#
#   GHG Only Label Combined Label
# 0            Red            Red

# %%
all_prod = pd.read_csv("data2/preprocessed/Products_List.csv")
all_prod
# Out:
#       ProdId                     Description        SalesGroup
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO
# ..       ...                             ...               ...
# 453  R-57815  SQR|Tofu Sofrito Quesadilla +1  OK - SQUARE MEAL
# 454  R-61679  SQR|Tofu Sofrito Quesadilla +2  OK - SQUARE MEAL
# 455  R-56902          SQR|Vegan Lettuce Wrap  OK - SQUARE MEAL
# 456  R-57810       SQR|Vegan Lettuce Wrap +1  OK - SQUARE MEAL
# 457  R-57811       SQR|Vegan Lettuce Wrap +2  OK - SQUARE MEAL
#
# [458 rows x 3 columns]

# %%
OK21.loc[OK21["ProdId"] == ""]
# Out:
# Empty DataFrame
# Columns: [ProdId, Description, SalesGroup, Weight (g), GHG Emission (g), N lost (g), Freshwater Withdrawals (L), Stress-Weighted Water Use (L), GHG Emission (g) / 100g, N lost (g) / 100g, Freshwater Withdrawals (L) / 100g, Stress-Weighted Water Use (L) / 100g, GHG Only Label, Combined Label]
# Index: []

# %%
weight = pd.read_csv("practice/weight_check.csv")
weight
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
weight.loc[weight["ProdId"] == "R-51217"]
# Out:
#       ProdId             Description           SalesGroup  Weight (g)  \
# 459  R-51217  BNO|Burrito|Super Tofu  OK - CUSTOM KITCHEN  705.000002
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 459       1165.055172    7.520257                209962.306627
#
#      Stress-Weighted Water Use (ml)
# 459                    4.004617e+06

# %%
prod_error0 = pd.read_csv("practice/products_check0.csv")
prod_error0
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO           0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO           0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO           0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO           0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO           0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL           0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL           0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL           0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL           0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL           0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
prod_error = pd.read_csv("practice/products_check.csv")
prod_error
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO        90.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       100.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       115.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO        75.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL         0.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL        16.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL         0.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL        85.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL        85.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
prod_error.loc[prod_error["ProdId"] == "R-51217"]
# Out:
#       ProdId             Description           SalesGroup  Weight (g)  \
# 459  R-51217  BNO|Burrito|Super Tofu  OK - CUSTOM KITCHEN   75.000002
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 459        114.187503        1.11                 31440.000786
#
#      Stress-Weighted Water Use (ml)
# 459                   961627.524041

# %%
prod_error2 = pd.read_csv("practice/products_check2.csv")
prod_error2
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
prod_error2.loc[prod_error2["ProdId"] == "R-51217"]
# Out:
#       ProdId             Description           SalesGroup  Weight (g)  \
# 459  R-51217  BNO|Burrito|Super Tofu  OK - CUSTOM KITCHEN  705.000002
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 459       1165.055172    7.520257                209962.306627
#
#      Stress-Weighted Water Use (ml)
# 459                    4.004617e+06

# %%
conversions
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 630       I-9641    0.017544             1.0           LOAF         57.00
# 631      I-14190    0.001667             1.0           LOAF        600.00
# 632      I-37113    0.004274             1.0             ea        234.00
# 633       I-1271    0.000111             0.1           LOAF        900.00
# 634      I-68718    0.011765             1.0           each         85.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# ...

# %%
prod_error3 = pd.read_csv("practice/products_check3.csv")
prod_error3
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# ...

# %%
prod_error3.loc[prod_error3["ProdId"] == "R-51217"]
# Out:
#       ProdId             Description           SalesGroup  Weight (g)  \
# 459  R-51217  BNO|Burrito|Super Tofu  OK - CUSTOM KITCHEN  705.000002
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 459       1165.055172    7.520257                209962.306627
#
#      Stress-Weighted Water Use (ml)
# 459                    4.004617e+06

# %%
prod_error3.loc[prod_error3["ProdId"] == "R-32124"]
# Out:
#       ProdId    Description             SalesGroup  Weight (g)  \
# 467  R-32124  ADD|Guacamole  OK - SANDWICH KITCHEN        45.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 467         52.969092    0.378894                  1500.838682
#
#      Stress-Weighted Water Use (ml)
# 467                    57219.597901

# %%
prod_error4 = pd.read_csv("practice/products_check4.csv")
prod_error4
# Out:
#       ProdId                     Description        SalesGroup  Weight (g)  \
# 0    R-61778          ALF|Flatbread|4 Cheese     OK - AL FORNO       185.0
# 1    R-61780  ALF|Flatbread|Apple & Pancetta     OK - AL FORNO       140.0
# 2    R-61749       ALF|Flatbread|BBQ Chicken     OK - AL FORNO       245.0
# 3    R-50859        ALF|Flatbread|Bruschetta     OK - AL FORNO       215.0
# 4    R-50788           ALF|Flatbread|Caprese     OK - AL FORNO       233.0
# ..       ...                             ...               ...         ...
# 605  R-51282       SQR|MushroomsRoasted 150g  OK - SQUARE MEAL       150.0
# 606  R-35910   SQR|PASTA|SundriedTomato 250g  OK - SQUARE MEAL       266.0
# 607  R-51320       SQR|Steamed|Broccoli 150g  OK - SQUARE MEAL       150.0
# 608  R-62495             SQR|Thai Beef Salad  OK - SQUARE MEAL       376.0
# 609  R-62496            SQR|Thai Tempe Salad  OK - SQUARE MEAL       356.0
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (L)  \
# ...

# %%
ingre
# Out:
#      IngredientId     Qty    Uom  Conversion  InvFactor   Recipe
# 0         P-18746    1.00     Kg    1.000000     1.0000  P-10241
# 1          I-3388    1.00      L    1.000000     0.3058  P-10496
# 2          I-4660    2.27     Kg    2.204620     0.6942  P-10496
# 3          I-3451    2.56      L    1.000000     1.2800  P-13933
# 4          I-4679    1.00  BUNCH    1.000000     0.0063  P-18318
# ...           ...     ...    ...         ...        ...      ...
# 6705      P-54344    1.00    tsp    0.004733     1.0000  R-62630
# 6706      P-62629    2.00   each    1.000000     1.0000  R-62630
# 6707      P-62632   50.00      g    0.001000     1.0000  R-62633
# 6708      P-54344    1.00    tsp    0.004733     1.0000  R-62638
# 6709      P-62637  120.00      g    0.002205     1.0000  R-62638
#
# [6710 rows x 6 columns]

# %%
ingre.loc[ingre["Recipe"] == "R-51217"]
# Out:
#      IngredientId    Qty Uom  Conversion  InvFactor   Recipe
# 5426       I-1152    1.0  CT       1.000        1.0  R-51217
# 5427      P-26062   90.0   g       0.001        1.0  R-51217
# 5428      P-26331  110.0   g       0.001        1.0  R-51217
# 5429      P-41573  120.0   g       0.001        1.0  R-51217
# 5430      P-41574   90.0  ml       0.001        1.0  R-51217
# 5431      P-50795   90.0   g       1.000        1.0  R-51217
# 5432      P-55548   40.0   g       0.001        1.0  R-51217
# 5433      P-56398   90.0   g       0.001        1.0  R-51217

# %%
weight.loc[weight["ProdId"] == "R-61655"]
# Out:
#       ProdId            Description              SalesGroup  Weight (g)  \
# 249  R-61655  GRL|Salad|Caesar|SIDE  OK - GRILL KITCHEN DAY       175.5
#
#      GHG Emission (g)  N lost (g)  Freshwater Withdrawals (ml)  \
# 249         326.37177    2.243562                 33755.769381
#
#      Stress-Weighted Water Use (ml)
# 249                    1.530982e+06
